# %%
import numpy as np
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
df = pd.read_csv('Final.csv')
df
# Out:
#                                         Alloy     Tg      Tx      Tl   Dmax  \
# 0    Hf47Cu29.25Ni9.75Al14                     790.0  875.0   1278.0  10.00
# 1    Hf48Cu29.25Ni9.75Al13                     785.0  874.0   1280.0  10.00
# 2    Cu55Zr42.5Ga2.5                           709.0  762.0   1199.0  1.00
# 3    Cu57.5Zr37.5Ga5                           745.0  785.0   1241.0  1.00
# 4    Cu52.5Zr40Ga7.5                           744.0  777.0   1218.0  1.50
# 5    Cu55Zr40Ga5                               736.0  779.0   1193.0  2.00
# 6    Cu52.5Zr42.5Ga5                           733.0  777.0   1187.0  2.00
# 7    Cu46Zr54                                  696.0  746.0   1201.0  2.00
# 8    Cu46Zr47Al7                               705.0  781.0   1163.0  3.00
# 9    Cu46Zr37Al7Y10                            665.0  743.0   1118.0  4.00
# 10   Cu46Zr45Al7Y2                             693.0  770.0   1143.0  8.00
# ...

# %%
train, test = train_test_split(df, test_size = 0.2, random_state = 1)

# %%
uniqueValues = train['Fabrication_Method'].unique()
print(uniqueValues)
# Out:
# ['Cu mold' 'Cu mold S' 'Cu mold I' 'Cu mold W' 'Cu moldD' 'Brass M'
#  'Cu moldC' 'SiO2 tube' 'CLELP' 'Melt Spin' 'Cu mold HPDC']

# %%
grouped = train.groupby(train.Fabrication_Method)

# %%
Cu_mold      = grouped.get_group("Cu mold")
Cu_mold_S    = grouped.get_group("Cu mold S")
Cu_mold_I    = grouped.get_group("Cu mold I")
Cu_mold_W    = grouped.get_group("Cu mold W")
Cu_mold_C    = grouped.get_group("Cu moldC")
Cu_mold_HPDC = grouped.get_group("Cu mold HPDC")
Melt_spin    = grouped.get_group("Melt Spin")
SiO2_tube    = grouped.get_group("SiO2 tube")
Cu_mold_D    = grouped.get_group("Cu moldD")
Brass_M      = grouped.get_group("Brass M")
CLELP        = grouped.get_group("CLELP")

# %% [markdown]
# # Alloy clustering of Cu_mold

# %%
Cu_Cu_mold = Cu_mold[Cu_mold['Alloy'].str.startswith('Cu') | Cu_mold['Alloy'].str.startswith('(Cu')]
Ca_Cu_mold = Cu_mold[Cu_mold['Alloy'].str.startswith('Ca')]
Mg_Cu_mold = Cu_mold[Cu_mold['Alloy'].str.startswith('Mg')]
La_Cu_mold = Cu_mold[Cu_mold['Alloy'].str.startswith('La')]
Pd_Cu_mold = Cu_mold[Cu_mold['Alloy'].str.startswith('Pd')]
Ti_Cu_mold = Cu_mold[Cu_mold['Alloy'].str.startswith('Ti') | Cu_mold['Alloy'].str.startswith('(Ti')]
Co_Cu_mold = Cu_mold[Cu_mold['Alloy'].str.startswith('Co')]
Au_Cu_mold = Cu_mold[Cu_mold['Alloy'].str.startswith('Au')]
Ag_Cu_mold = Cu_mold[Cu_mold['Alloy'].str.startswith('Ag')]
Hf_Cu_mold = Cu_mold[Cu_mold['Alloy'].str.startswith('Hf')]
Gd_Cu_mold = Cu_mold[Cu_mold['Alloy'].str.startswith('Gd')]
Zr_Cu_mold = Cu_mold[Cu_mold['Alloy'].str.startswith('Zr') | Cu_mold['Alloy'].str.startswith('(Zr')]
Ni_Cu_mold = Cu_mold[Cu_mold['Alloy'].str.startswith('Ni')]
Pr_Cu_mold = Cu_mold[Cu_mold['Alloy'].str.startswith('Pr')]
Y_Cu_mold = Cu_mold[Cu_mold['Alloy'].str.startswith('Y')   | Cu_mold['Alloy'].str.startswith('(Y')]
Fe_Cu_mold = Cu_mold[Cu_mold['Alloy'].str.startswith('Fe') | Cu_mold['Alloy'].str.startswith('(Fe') | Cu_mold['Alloy'].str.startswith('[(Fe')]

# %%
Cu_Cu_mold['Alloy'].count()+Ca_Cu_mold['Alloy'].count()+Mg_Cu_mold['Alloy'].count()+La_Cu_mold['Alloy'].count()+Pd_Cu_mold['Alloy'].count()+Ti_Cu_mold['Alloy'].count()+Co_Cu_mold['Alloy'].count()+Au_Cu_mold['Alloy'].count()+Hf_Cu_mold['Alloy'].count()+Gd_Cu_mold['Alloy'].count()+Zr_Cu_mold['Alloy'].count()+Ni_Cu_mold['Alloy'].count()+Pr_Cu_mold['Alloy'].count()+Y_Cu_mold['Alloy'].count()+Fe_Cu_mold['Alloy'].count()
# Out:
# 211

# %%
Cu_mold.count()
# Out:
# Alloy                 211
# Tg                    211
# Tx                    211
# Tl                    211
# Dmax                  211
# Heating_Rate1         211
# Heating_Rate2         211
# Fabrication_Method    211
# No of Elements        211
# dtype: int64

# %% [markdown]
# # Alloy clustering of Cu_mold_S

# %%
Cu_Cu_mold_S = Cu_mold_S[Cu_mold_S['Alloy'].str.startswith('Cu') | Cu_mold_S['Alloy'].str.startswith('(Cu')]
Ca_Cu_mold_S = Cu_mold_S[Cu_mold_S['Alloy'].str.startswith('Ca')]
Mg_Cu_mold_S = Cu_mold_S[Cu_mold_S['Alloy'].str.startswith('Mg')]
La_Cu_mold_S = Cu_mold_S[Cu_mold_S['Alloy'].str.startswith('La')]
Pd_Cu_mold_S = Cu_mold_S[Cu_mold_S['Alloy'].str.startswith('Pd')]
Ti_Cu_mold_S = Cu_mold_S[Cu_mold_S['Alloy'].str.startswith('Ti') | Cu_mold_S['Alloy'].str.startswith('(Ti')]
Co_Cu_mold_S = Cu_mold_S[Cu_mold_S['Alloy'].str.startswith('Co')]
Au_Cu_mold_S = Cu_mold_S[Cu_mold_S['Alloy'].str.startswith('Au')]
Ag_Cu_mold_S = Cu_mold_S[Cu_mold_S['Alloy'].str.startswith('Ag')]
Hf_Cu_mold_S = Cu_mold_S[Cu_mold_S['Alloy'].str.startswith('Hf')]
Gd_Cu_mold_S = Cu_mold_S[Cu_mold_S['Alloy'].str.startswith('Gd')]
Zr_Cu_mold_S = Cu_mold_S[Cu_mold_S['Alloy'].str.startswith('Zr') | Cu_mold_S['Alloy'].str.startswith('(Zr')]
Ni_Cu_mold_S = Cu_mold_S[Cu_mold_S['Alloy'].str.startswith('Ni')]
Pr_Cu_mold_S = Cu_mold_S[Cu_mold_S['Alloy'].str.startswith('Pr')]
Y_Cu_mold_S = Cu_mold_S[Cu_mold_S['Alloy'].str.startswith('Y')   | Cu_mold_S['Alloy'].str.startswith('(Y')]
Fe_Cu_mold_S = Cu_mold_S[Cu_mold_S['Alloy'].str.startswith('Fe') | Cu_mold_S['Alloy'].str.startswith('(Fe') | Cu_mold_S['Alloy'].str.startswith('[(Fe')]

# %% [markdown]
# # Alloy clustering of Cu_mold_I

# %%
Cu_Cu_mold_I = Cu_mold_I[Cu_mold_I['Alloy'].str.startswith('Cu') | Cu_mold_I['Alloy'].str.startswith('(Cu')]
Ca_Cu_mold_I = Cu_mold_I[Cu_mold_I['Alloy'].str.startswith('Ca')]
Mg_Cu_mold_I = Cu_mold_I[Cu_mold_I['Alloy'].str.startswith('Mg')]
La_Cu_mold_I = Cu_mold_I[Cu_mold_I['Alloy'].str.startswith('La')]
Pd_Cu_mold_I = Cu_mold_I[Cu_mold_I['Alloy'].str.startswith('Pd')]
Ti_Cu_mold_I = Cu_mold_I[Cu_mold_I['Alloy'].str.startswith('Ti') | Cu_mold_I['Alloy'].str.startswith('(Ti')]
Co_Cu_mold_I = Cu_mold_I[Cu_mold_I['Alloy'].str.startswith('Co')]
Au_Cu_mold_I = Cu_mold_I[Cu_mold_I['Alloy'].str.startswith('Au')]
Ag_Cu_mold_I = Cu_mold_I[Cu_mold_I['Alloy'].str.startswith('Ag')]
Hf_Cu_mold_I = Cu_mold_I[Cu_mold_I['Alloy'].str.startswith('Hf')]
Gd_Cu_mold_I = Cu_mold_I[Cu_mold_I['Alloy'].str.startswith('Gd')]
Zr_Cu_mold_I = Cu_mold_I[Cu_mold_I['Alloy'].str.startswith('Zr') | Cu_mold_I['Alloy'].str.startswith('(Zr')]
Ni_Cu_mold_I = Cu_mold_I[Cu_mold_I['Alloy'].str.startswith('Ni')]
Pr_Cu_mold_I = Cu_mold_I[Cu_mold_I['Alloy'].str.startswith('Pr')]
Y_Cu_mold_I = Cu_mold_I[Cu_mold_I['Alloy'].str.startswith('Y')   | Cu_mold_I['Alloy'].str.startswith('(Y')]
Fe_Cu_mold_I = Cu_mold_I[Cu_mold_I['Alloy'].str.startswith('Fe') | Cu_mold_I['Alloy'].str.startswith('(Fe') | Cu_mold_I['Alloy'].str.startswith('[(Fe')]

# %%
Zr_Cu_mold_I['Alloy'].count()
# Out:
# 18

# %%
Cu_mold_I.count()
# Out:
# Alloy                 136
# Tg                    136
# Tx                    136
# Tl                    136
# Dmax                  136
# Heating_Rate1         136
# Heating_Rate2         136
# Fabrication_Method    136
# No of Elements        136
# dtype: int64

# %% [markdown]
# # Alloy clustering of Cu_mold_W

# %%
Cu_Cu_mold_W = Cu_mold_W[Cu_mold_W['Alloy'].str.startswith('Cu') | Cu_mold_W['Alloy'].str.startswith('(Cu')]
Ca_Cu_mold_W = Cu_mold_W[Cu_mold_W['Alloy'].str.startswith('Ca')]
Mg_Cu_mold_W = Cu_mold_W[Cu_mold_W['Alloy'].str.startswith('Mg')]
La_Cu_mold_W = Cu_mold_W[Cu_mold_W['Alloy'].str.startswith('La')]
Pd_Cu_mold_W = Cu_mold_W[Cu_mold_W['Alloy'].str.startswith('Pd')]
Ti_Cu_mold_W = Cu_mold_W[Cu_mold_W['Alloy'].str.startswith('Ti') | Cu_mold_W['Alloy'].str.startswith('(Ti')]
Co_Cu_mold_W = Cu_mold_W[Cu_mold_W['Alloy'].str.startswith('Co')]
Au_Cu_mold_W = Cu_mold_W[Cu_mold_W['Alloy'].str.startswith('Au')]
Ag_Cu_mold_W = Cu_mold_W[Cu_mold_W['Alloy'].str.startswith('Ag')]
Hf_Cu_mold_W = Cu_mold_W[Cu_mold_W['Alloy'].str.startswith('Hf')]
Gd_Cu_mold_W = Cu_mold_W[Cu_mold_W['Alloy'].str.startswith('Gd')]
Zr_Cu_mold_W = Cu_mold_W[Cu_mold_W['Alloy'].str.startswith('Zr') | Cu_mold_W['Alloy'].str.startswith('(Zr')]
Ni_Cu_mold_W = Cu_mold_W[Cu_mold_W['Alloy'].str.startswith('Ni')]
Pr_Cu_mold_W = Cu_mold_W[Cu_mold_W['Alloy'].str.startswith('Pr')]
Y_Cu_mold_W = Cu_mold_W[Cu_mold_W['Alloy'].str.startswith('Y')   | Cu_mold_W['Alloy'].str.startswith('(Y')]
Fe_Cu_mold_W = Cu_mold_W[Cu_mold_W['Alloy'].str.startswith('Fe') | Cu_mold_W['Alloy'].str.startswith('(Fe') | Cu_mold_W['Alloy'].str.startswith('[(Fe')]

# %%
Cu_Cu_mold_W['Alloy'].count()+Ca_Cu_mold_W['Alloy'].count()+Mg_Cu_mold_W['Alloy'].count()+La_Cu_mold_W['Alloy'].count()+Pd_Cu_mold_W['Alloy'].count()+Ti_Cu_mold_W['Alloy'].count()+Co_Cu_mold_W['Alloy'].count()+Au_Cu_mold_W['Alloy'].count()+Hf_Cu_mold_W['Alloy'].count()+Gd_Cu_mold_W['Alloy'].count()+Zr_Cu_mold_W['Alloy'].count()+Ni_Cu_mold_W['Alloy'].count()+Pr_Cu_mold_W['Alloy'].count()+Y_Cu_mold_W['Alloy'].count()+Fe_Cu_mold_W['Alloy'].count()
# Out:
# 43

# %%
Cu_mold_W.count()
# Out:
# Alloy                 43
# Tg                    43
# Tx                    43
# Tl                    43
# Dmax                  43
# Heating_Rate1         43
# Heating_Rate2         43
# Fabrication_Method    43
# No of Elements        43
# dtype: int64

# %% [markdown]
# # Alloy clustering of Cu_mold_C

# %%
Cu_Cu_mold_C = Cu_mold_C[Cu_mold_C['Alloy'].str.startswith('Cu') | Cu_mold_C['Alloy'].str.startswith('(Cu')]
Ca_Cu_mold_C = Cu_mold_C[Cu_mold_C['Alloy'].str.startswith('Ca')]
Mg_Cu_mold_C = Cu_mold_C[Cu_mold_C['Alloy'].str.startswith('Mg')]
La_Cu_mold_C = Cu_mold_C[Cu_mold_C['Alloy'].str.startswith('La')]
Pd_Cu_mold_C = Cu_mold_C[Cu_mold_C['Alloy'].str.startswith('Pd')]
Ti_Cu_mold_C = Cu_mold_C[Cu_mold_C['Alloy'].str.startswith('Ti') | Cu_mold_C['Alloy'].str.startswith('(Ti')]
Co_Cu_mold_C = Cu_mold_C[Cu_mold_C['Alloy'].str.startswith('Co')]
Au_Cu_mold_C = Cu_mold_C[Cu_mold_C['Alloy'].str.startswith('Au')]
Ag_Cu_mold_C = Cu_mold_C[Cu_mold_C['Alloy'].str.startswith('Ag')]
Hf_Cu_mold_C = Cu_mold_C[Cu_mold_C['Alloy'].str.startswith('Hf')]
Gd_Cu_mold_C = Cu_mold_C[Cu_mold_C['Alloy'].str.startswith('Gd')]
Zr_Cu_mold_C = Cu_mold_C[Cu_mold_C['Alloy'].str.startswith('Zr') | Cu_mold_C['Alloy'].str.startswith('(Zr')]
Ni_Cu_mold_C = Cu_mold_C[Cu_mold_C['Alloy'].str.startswith('Ni')]
Pr_Cu_mold_C = Cu_mold_C[Cu_mold_C['Alloy'].str.startswith('Pr')]
Y_Cu_mold_C = Cu_mold_C[Cu_mold_C['Alloy'].str.startswith('Y')   | Cu_mold_C['Alloy'].str.startswith('(Y')]
Fe_Cu_mold_C = Cu_mold_C[Cu_mold_C['Alloy'].str.startswith('Fe') | Cu_mold_C['Alloy'].str.startswith('(Fe') | Cu_mold_C['Alloy'].str.startswith('[(Fe')]

# %%
Cu_Cu_mold_C['Alloy'].count()+Ca_Cu_mold_C['Alloy'].count()+Mg_Cu_mold_C['Alloy'].count()+La_Cu_mold_C['Alloy'].count()+Pd_Cu_mold_C['Alloy'].count()+Ti_Cu_mold_C['Alloy'].count()+Co_Cu_mold_C['Alloy'].count()+Au_Cu_mold_C['Alloy'].count()+Hf_Cu_mold_C['Alloy'].count()+Gd_Cu_mold_C['Alloy'].count()+Zr_Cu_mold_C['Alloy'].count()+Ni_Cu_mold_C['Alloy'].count()+Pr_Cu_mold_C['Alloy'].count()+Y_Cu_mold_C['Alloy'].count()+Fe_Cu_mold_C['Alloy'].count()
# Out:
# 2

# %%
Cu_mold_C.count()
# Out:
# Alloy                 2
# Tg                    2
# Tx                    2
# Tl                    2
# Dmax                  2
# Heating_Rate1         2
# Heating_Rate2         2
# Fabrication_Method    2
# No of Elements        2
# dtype: int64

# %% [markdown]
# # Alloy clustering of Cu_mold_HPDC

# %%
Cu_Cu_mold_HPDC = Cu_mold_HPDC[Cu_mold_HPDC['Alloy'].str.startswith('Cu') | Cu_mold_HPDC['Alloy'].str.startswith('(Cu')]
Ca_Cu_mold_HPDC = Cu_mold_HPDC[Cu_mold_HPDC['Alloy'].str.startswith('Ca')]
Mg_Cu_mold_HPDC = Cu_mold_HPDC[Cu_mold_HPDC['Alloy'].str.startswith('Mg')]
La_Cu_mold_HPDC = Cu_mold_HPDC[Cu_mold_HPDC['Alloy'].str.startswith('La')]
Pd_Cu_mold_HPDC = Cu_mold_HPDC[Cu_mold_HPDC['Alloy'].str.startswith('Pd')]
Ti_Cu_mold_HPDC = Cu_mold_HPDC[Cu_mold_HPDC['Alloy'].str.startswith('Ti') | Cu_mold_HPDC['Alloy'].str.startswith('(Ti')]
Co_Cu_mold_HPDC = Cu_mold_HPDC[Cu_mold_HPDC['Alloy'].str.startswith('Co')]
Au_Cu_mold_HPDC = Cu_mold_HPDC[Cu_mold_HPDC['Alloy'].str.startswith('Au')]
Ag_Cu_mold_HPDC = Cu_mold_HPDC[Cu_mold_HPDC['Alloy'].str.startswith('Ag')]
Hf_Cu_mold_HPDC = Cu_mold_HPDC[Cu_mold_HPDC['Alloy'].str.startswith('Hf')]
Gd_Cu_mold_HPDC = Cu_mold_HPDC[Cu_mold_HPDC['Alloy'].str.startswith('Gd')]
Zr_Cu_mold_HPDC = Cu_mold_HPDC[Cu_mold_HPDC['Alloy'].str.startswith('Zr') | Cu_mold_HPDC['Alloy'].str.startswith('(Zr')]
Ni_Cu_mold_HPDC = Cu_mold_HPDC[Cu_mold_HPDC['Alloy'].str.startswith('Ni')]
Pr_Cu_mold_HPDC = Cu_mold_HPDC[Cu_mold_HPDC['Alloy'].str.startswith('Pr')]
Y_Cu_mold_HPDC = Cu_mold_HPDC[Cu_mold_HPDC['Alloy'].str.startswith('Y')   | Cu_mold_HPDC['Alloy'].str.startswith('(Y')]
Fe_Cu_mold_HPDC = Cu_mold_HPDC[Cu_mold_HPDC['Alloy'].str.startswith('Fe') | Cu_mold_HPDC['Alloy'].str.startswith('(Fe') | Cu_mold_HPDC['Alloy'].str.startswith('[(Fe')]

# %%
Cu_Cu_mold_HPDC['Alloy'].count()+Ca_Cu_mold_HPDC['Alloy'].count()+Mg_Cu_mold_HPDC['Alloy'].count()+La_Cu_mold_HPDC['Alloy'].count()+Pd_Cu_mold_HPDC['Alloy'].count()+Ti_Cu_mold_HPDC['Alloy'].count()+Co_Cu_mold_HPDC['Alloy'].count()+Au_Cu_mold_HPDC['Alloy'].count()+Hf_Cu_mold_HPDC['Alloy'].count()+Gd_Cu_mold_HPDC['Alloy'].count()+Zr_Cu_mold_HPDC['Alloy'].count()+Ni_Cu_mold_HPDC['Alloy'].count()+Pr_Cu_mold_HPDC['Alloy'].count()+Y_Cu_mold_HPDC['Alloy'].count()+Fe_Cu_mold_HPDC['Alloy'].count()
# Out:
# 3

# %%
Cu_mold_HPDC.count()
# Out:
# Alloy                 3
# Tg                    3
# Tx                    3
# Tl                    3
# Dmax                  3
# Heating_Rate1         3
# Heating_Rate2         3
# Fabrication_Method    3
# No of Elements        3
# dtype: int64

# %% [markdown]
# # Alloy clustering of Melt Spin

# %%
Cu_Melt_spin = Melt_spin[Melt_spin['Alloy'].str.startswith('Cu') | Melt_spin['Alloy'].str.startswith('(Cu')]
Ca_Melt_spin = Melt_spin[Melt_spin['Alloy'].str.startswith('Ca')]
Mg_Melt_spin = Melt_spin[Melt_spin['Alloy'].str.startswith('Mg')]
La_Melt_spin = Melt_spin[Melt_spin['Alloy'].str.startswith('La')]
Pd_Melt_spin = Melt_spin[Melt_spin['Alloy'].str.startswith('Pd')]
Ti_Melt_spin = Melt_spin[Melt_spin['Alloy'].str.startswith('Ti') | Melt_spin['Alloy'].str.startswith('(Ti')]
Co_Melt_spin = Melt_spin[Melt_spin['Alloy'].str.startswith('Co')]
Au_Melt_spin = Melt_spin[Melt_spin['Alloy'].str.startswith('Au')]
Ag_Melt_spin = Melt_spin[Melt_spin['Alloy'].str.startswith('Ag')]
Hf_Melt_spin = Melt_spin[Melt_spin['Alloy'].str.startswith('Hf')]
Gd_Melt_spin = Melt_spin[Melt_spin['Alloy'].str.startswith('Gd')]
Zr_Melt_spin = Melt_spin[Melt_spin['Alloy'].str.startswith('Zr') | Melt_spin['Alloy'].str.startswith('(Zr')]
Ni_Melt_spin = Melt_spin[Melt_spin['Alloy'].str.startswith('Ni')]
Pr_Melt_spin = Melt_spin[Melt_spin['Alloy'].str.startswith('Pr')]
Y_Melt_spin = Melt_spin[Melt_spin['Alloy'].str.startswith('Y')   | Melt_spin['Alloy'].str.startswith('(Y')]
Fe_Melt_spin = Melt_spin[Melt_spin['Alloy'].str.startswith('Fe') | Melt_spin['Alloy'].str.startswith('(Fe') | Melt_spin['Alloy'].str.startswith('[(Fe')]

# %%
Cu_Melt_spin['Alloy'].count()+Ca_Melt_spin['Alloy'].count()+Mg_Melt_spin['Alloy'].count()+La_Melt_spin['Alloy'].count()+Pd_Melt_spin['Alloy'].count()+Ti_Melt_spin['Alloy'].count()+Co_Melt_spin['Alloy'].count()+Au_Melt_spin['Alloy'].count()+Hf_Melt_spin['Alloy'].count()+Gd_Melt_spin['Alloy'].count()+Zr_Melt_spin['Alloy'].count()+Ni_Melt_spin['Alloy'].count()+Pr_Melt_spin['Alloy'].count()+Y_Melt_spin['Alloy'].count()+Fe_Melt_spin['Alloy'].count()
# Out:
# 2

# %%
Melt_spin.count()
# Out:
# Alloy                 2
# Tg                    2
# Tx                    2
# Tl                    2
# Dmax                  2
# Heating_Rate1         2
# Heating_Rate2         2
# Fabrication_Method    2
# No of Elements        2
# dtype: int64

# %% [markdown]
# # Alloy clustering of SiO2 Tube

# %%
Cu_SiO2_tube = SiO2_tube[SiO2_tube['Alloy'].str.startswith('Cu') | SiO2_tube['Alloy'].str.startswith('(Cu')]
Ca_SiO2_tube = SiO2_tube[SiO2_tube['Alloy'].str.startswith('Ca')]
Mg_SiO2_tube = SiO2_tube[SiO2_tube['Alloy'].str.startswith('Mg')]
La_SiO2_tube = SiO2_tube[SiO2_tube['Alloy'].str.startswith('La')]
Pd_SiO2_tube = SiO2_tube[SiO2_tube['Alloy'].str.startswith('Pd')]
Ti_SiO2_tube = SiO2_tube[SiO2_tube['Alloy'].str.startswith('Ti') | SiO2_tube['Alloy'].str.startswith('(Ti')]
Co_SiO2_tube = SiO2_tube[SiO2_tube['Alloy'].str.startswith('Co')]
Au_SiO2_tube = SiO2_tube[SiO2_tube['Alloy'].str.startswith('Au')]
Ag_SiO2_tube = SiO2_tube[SiO2_tube['Alloy'].str.startswith('Ag')]
Hf_SiO2_tube = SiO2_tube[SiO2_tube['Alloy'].str.startswith('Hf')]
Gd_SiO2_tube = SiO2_tube[SiO2_tube['Alloy'].str.startswith('Gd')]
Zr_SiO2_tube = SiO2_tube[SiO2_tube['Alloy'].str.startswith('Zr') | SiO2_tube['Alloy'].str.startswith('(Zr')]
Ni_SiO2_tube = SiO2_tube[SiO2_tube['Alloy'].str.startswith('Ni')]
Pr_SiO2_tube = SiO2_tube[SiO2_tube['Alloy'].str.startswith('Pr')]
Y_SiO2_tube = SiO2_tube[SiO2_tube['Alloy'].str.startswith('Y')   | SiO2_tube['Alloy'].str.startswith('(Y')]
Fe_SiO2_tube = SiO2_tube[SiO2_tube['Alloy'].str.startswith('Fe') | SiO2_tube['Alloy'].str.startswith('(Fe') | SiO2_tube['Alloy'].str.startswith('[(Fe')]

# %%
Cu_SiO2_tube['Alloy'].count()+Ca_SiO2_tube['Alloy'].count()+Mg_SiO2_tube['Alloy'].count()+La_SiO2_tube['Alloy'].count()+Pd_SiO2_tube['Alloy'].count()+Ti_SiO2_tube['Alloy'].count()+Co_SiO2_tube['Alloy'].count()+Au_SiO2_tube['Alloy'].count()+Hf_SiO2_tube['Alloy'].count()+Gd_SiO2_tube['Alloy'].count()+Zr_SiO2_tube['Alloy'].count()+Ni_SiO2_tube['Alloy'].count()+Pr_SiO2_tube['Alloy'].count()+Y_SiO2_tube['Alloy'].count()+Fe_SiO2_tube['Alloy'].count()
# Out:
# 5

# %%
SiO2_tube.count()
# Out:
# Alloy                 5
# Tg                    5
# Tx                    5
# Tl                    5
# Dmax                  5
# Heating_Rate1         5
# Heating_Rate2         5
# Fabrication_Method    5
# No of Elements        5
# dtype: int64

# %% [markdown]
# # Alloy clustering of Cu mold D

# %%
Cu_Cu_mold_D = Cu_mold_D[Cu_mold_D['Alloy'].str.startswith('Cu') | Cu_mold_D['Alloy'].str.startswith('(Cu')]
Ca_Cu_mold_D = Cu_mold_D[Cu_mold_D['Alloy'].str.startswith('Ca')]
Mg_Cu_mold_D = Cu_mold_D[Cu_mold_D['Alloy'].str.startswith('Mg')]
La_Cu_mold_D = Cu_mold_D[Cu_mold_D['Alloy'].str.startswith('La')]
Pd_Cu_mold_D = Cu_mold_D[Cu_mold_D['Alloy'].str.startswith('Pd')]
Ti_Cu_mold_D = Cu_mold_D[Cu_mold_D['Alloy'].str.startswith('Ti') | Cu_mold_D['Alloy'].str.startswith('(Ti')]
Co_Cu_mold_D = Cu_mold_D[Cu_mold_D['Alloy'].str.startswith('Co')]
Au_Cu_mold_D = Cu_mold_D[Cu_mold_D['Alloy'].str.startswith('Au')]
Ag_Cu_mold_D = Cu_mold_D[Cu_mold_D['Alloy'].str.startswith('Ag')]
Hf_Cu_mold_D = Cu_mold_D[Cu_mold_D['Alloy'].str.startswith('Hf')]
Gd_Cu_mold_D = Cu_mold_D[Cu_mold_D['Alloy'].str.startswith('Gd')]
Zr_Cu_mold_D = Cu_mold_D[Cu_mold_D['Alloy'].str.startswith('Zr') | Cu_mold_D['Alloy'].str.startswith('(Zr')]
Ni_Cu_mold_D = Cu_mold_D[Cu_mold_D['Alloy'].str.startswith('Ni')]
Pr_Cu_mold_D = Cu_mold_D[Cu_mold_D['Alloy'].str.startswith('Pr')]
Y_Cu_mold_D = Cu_mold_D[Cu_mold_D['Alloy'].str.startswith('Y')   | Cu_mold_D['Alloy'].str.startswith('(Y')]
Fe_Cu_mold_D = Cu_mold_D[Cu_mold_D['Alloy'].str.startswith('Fe') | Cu_mold_D['Alloy'].str.startswith('(Fe') | Cu_mold_D['Alloy'].str.startswith('[(Fe')]

# %%
Cu_Cu_mold_D['Alloy'].count()+Ca_Cu_mold_D['Alloy'].count()+Mg_Cu_mold_D['Alloy'].count()+La_Cu_mold_D['Alloy'].count()+Pd_Cu_mold_D['Alloy'].count()+Ti_Cu_mold_D['Alloy'].count()+Co_Cu_mold_D['Alloy'].count()+Au_Cu_mold_D['Alloy'].count()+Hf_Cu_mold_D['Alloy'].count()+Gd_Cu_mold_D['Alloy'].count()+Zr_Cu_mold_D['Alloy'].count()+Ni_Cu_mold_D['Alloy'].count()+Pr_Cu_mold_D['Alloy'].count()+Y_Cu_mold_D['Alloy'].count()+Fe_Cu_mold_D['Alloy'].count()
# Out:
# 9

# %%
Cu_mold_D.count()
# Out:
# Alloy                 9
# Tg                    9
# Tx                    9
# Tl                    9
# Dmax                  9
# Heating_Rate1         9
# Heating_Rate2         9
# Fabrication_Method    9
# No of Elements        9
# dtype: int64

# %% [markdown]
# # Alloy clustering of Brass M

# %%
Cu_Brass_M = Brass_M[Brass_M['Alloy'].str.startswith('Cu') | Brass_M['Alloy'].str.startswith('(Cu')]
Ca_Brass_M = Brass_M[Brass_M['Alloy'].str.startswith('Ca')]
Mg_Brass_M = Brass_M[Brass_M['Alloy'].str.startswith('Mg')]
La_Brass_M = Brass_M[Brass_M['Alloy'].str.startswith('La')]
Pd_Brass_M = Brass_M[Brass_M['Alloy'].str.startswith('Pd')]
Ti_Brass_M = Brass_M[Brass_M['Alloy'].str.startswith('Ti') | Brass_M['Alloy'].str.startswith('(Ti')]
Co_Brass_M = Brass_M[Brass_M['Alloy'].str.startswith('Co')]
Au_Brass_M = Brass_M[Brass_M['Alloy'].str.startswith('Au')]
Ag_Brass_M = Brass_M[Brass_M['Alloy'].str.startswith('Ag')]
Hf_Brass_M = Brass_M[Brass_M['Alloy'].str.startswith('Hf')]
Gd_Brass_M = Brass_M[Brass_M['Alloy'].str.startswith('Gd')]
Zr_Brass_M = Brass_M[Brass_M['Alloy'].str.startswith('Zr') | Brass_M['Alloy'].str.startswith('(Zr')]
Ni_Brass_M = Brass_M[Brass_M['Alloy'].str.startswith('Ni')]
Pr_Brass_M = Brass_M[Brass_M['Alloy'].str.startswith('Pr')]
Y_Brass_M = Brass_M[Brass_M['Alloy'].str.startswith('Y')   | Brass_M['Alloy'].str.startswith('(Y')]
Fe_Brass_M = Brass_M[Brass_M['Alloy'].str.startswith('Fe') | Brass_M['Alloy'].str.startswith('(Fe') | Brass_M['Alloy'].str.startswith('[(Fe')]

# %%
Cu_Brass_M['Alloy'].count()+Ca_Brass_M['Alloy'].count()+Mg_Brass_M['Alloy'].count()+La_Brass_M['Alloy'].count()+Pd_Brass_M['Alloy'].count()+Ti_Brass_M['Alloy'].count()+Co_Brass_M['Alloy'].count()+Au_Brass_M['Alloy'].count()+Hf_Brass_M['Alloy'].count()+Gd_Brass_M['Alloy'].count()+Zr_Brass_M['Alloy'].count()+Ni_Brass_M['Alloy'].count()+Pr_Brass_M['Alloy'].count()+Y_Brass_M['Alloy'].count()+Fe_Brass_M['Alloy'].count()
# Out:
# 3

# %%
Brass_M.count()
# Out:
# Alloy                 3
# Tg                    3
# Tx                    3
# Tl                    3
# Dmax                  3
# Heating_Rate1         3
# Heating_Rate2         3
# Fabrication_Method    3
# No of Elements        3
# dtype: int64

# %% [markdown]
# # Alloy clustering of CLELP

# %%
Cu_CLELP = CLELP[CLELP['Alloy'].str.startswith('Cu') | CLELP['Alloy'].str.startswith('(Cu')]
Ca_CLELP = CLELP[CLELP['Alloy'].str.startswith('Ca')]
Mg_CLELP = CLELP[CLELP['Alloy'].str.startswith('Mg')]
La_CLELP = CLELP[CLELP['Alloy'].str.startswith('La')]
Pd_CLELP = CLELP[CLELP['Alloy'].str.startswith('Pd')]
Ti_CLELP = CLELP[CLELP['Alloy'].str.startswith('Ti') | CLELP['Alloy'].str.startswith('(Ti')]
Co_CLELP = CLELP[CLELP['Alloy'].str.startswith('Co')]
Au_CLELP = CLELP[CLELP['Alloy'].str.startswith('Au')]
Ag_CLELP = CLELP[CLELP['Alloy'].str.startswith('Ag')]
Hf_CLELP = CLELP[CLELP['Alloy'].str.startswith('Hf')]
Gd_CLELP = CLELP[CLELP['Alloy'].str.startswith('Gd')]
Zr_CLELP = CLELP[CLELP['Alloy'].str.startswith('Zr') | CLELP['Alloy'].str.startswith('(Zr')]
Ni_CLELP = CLELP[CLELP['Alloy'].str.startswith('Ni')]
Pr_CLELP = CLELP[CLELP['Alloy'].str.startswith('Pr')]
Y_CLELP =  CLELP[CLELP['Alloy'].str.startswith('Y')   | CLELP['Alloy'].str.startswith('(Y')]
Fe_CLELP = CLELP[CLELP['Alloy'].str.startswith('Fe') | CLELP['Alloy'].str.startswith('(Fe') | CLELP['Alloy'].str.startswith('[(Fe')]

# %%
Cu_CLELP['Alloy'].count()+Ca_CLELP['Alloy'].count()+Mg_CLELP['Alloy'].count()+La_CLELP['Alloy'].count()+Pd_CLELP['Alloy'].count()+Ti_CLELP['Alloy'].count()+Co_CLELP['Alloy'].count()+Au_CLELP['Alloy'].count()+Hf_CLELP['Alloy'].count()+Gd_CLELP['Alloy'].count()+Zr_CLELP['Alloy'].count()+Ni_CLELP['Alloy'].count()+Pr_CLELP['Alloy'].count()+Y_CLELP['Alloy'].count()+Fe_CLELP['Alloy'].count()
# Out:
# 1

# %%
CLELP.count()
# Out:
# Alloy                 1
# Tg                    1
# Tx                    1
# Tl                    1
# Dmax                  1
# Heating_Rate1         1
# Heating_Rate2         1
# Fabrication_Method    1
# No of Elements        1
# dtype: int64

# %% [markdown]
# # Clustering based on Number of Elements in Cu_Cu_mold

# %%
Cu_Cu_mold['Tg'].mean()
# Out:
# 713.9807692307693

# %%
def Cu(Tg,Tx,Tl,Dmax,Heating_Rate1,Heating_Rate2):
    distance=[]
    distance_1 = []
    
    distance.append(((Tg-Cu_Cu_mold['Tg'].mean())**2+(Tx-Cu_Cu_mold['Tx'].mean())**2+(Tl-Cu_Cu_mold['Tl'].mean())**2+(Dmax-Cu_Cu_mold['Dmax'].mean())**2+(Heating_Rate1-Cu_Cu_mold['Heating_Rate1'].mean())**2+(Heating_Rate2-Cu_Cu_mold['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Cu_Cu_mold_S['Tg'].mean())**2+(Tx-Cu_Cu_mold_S['Tx'].mean())**2+(Tl-Cu_Cu_mold_S['Tl'].mean())**2+(Dmax-Cu_Cu_mold_S['Dmax'].mean())**2+(Heating_Rate1-Cu_Cu_mold_S['Heating_Rate1'].mean())**2+(Heating_Rate2-Cu_Cu_mold_S['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Cu_Cu_mold_I['Tg'].mean())**2+(Tx-Cu_Cu_mold_I['Tx'].mean())**2+(Tl-Cu_Cu_mold_I['Tl'].mean())**2+(Dmax-Cu_Cu_mold_I['Dmax'].mean())**2+(Heating_Rate1-Cu_Cu_mold_I['Heating_Rate1'].mean())**2+(Heating_Rate2-Cu_Cu_mold_I['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Cu_Cu_mold_W['Tg'].mean())**2+(Tx-Cu_Cu_mold_W['Tx'].mean())**2+(Tl-Cu_Cu_mold_W['Tl'].mean())**2+(Dmax-Cu_Cu_mold_W['Dmax'].mean())**2+(Heating_Rate1-Cu_Cu_mold_W['Heating_Rate1'].mean())**2+(Heating_Rate2-Cu_Cu_mold_W['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Cu_Cu_mold_C['Tg'].mean())**2+(Tx-Cu_Cu_mold_C['Tx'].mean())**2+(Tl-Cu_Cu_mold_C['Tl'].mean())**2+(Dmax-Cu_Cu_mold_C['Dmax'].mean())**2+(Heating_Rate1-Cu_Cu_mold_C['Heating_Rate1'].mean())**2+(Heating_Rate2-Cu_Cu_mold_C['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Cu_Cu_mold_HPDC['Tg'].mean())**2+(Tx-Cu_Cu_mold_HPDC['Tx'].mean())**2+(Tl-Cu_Cu_mold_HPDC['Tl'].mean())**2+(Dmax-Cu_Cu_mold_HPDC['Dmax'].mean())**2+(Heating_Rate1-Cu_Cu_mold_HPDC['Heating_Rate1'].mean())**2+(Heating_Rate2-Cu_Cu_mold_HPDC['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Cu_Melt_spin['Tg'].mean())**2+(Tx-Cu_Melt_spin['Tx'].mean())**2+(Tl-Cu_Melt_spin['Tl'].mean())**2+(Dmax-Cu_Melt_spin['Dmax'].mean())**2+(Heating_Rate1-Cu_Melt_spin['Heating_Rate1'].mean())**2+(Heating_Rate2-Cu_Melt_spin['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Cu_SiO2_tube['Tg'].mean())**2+(Tx-Cu_SiO2_tube['Tx'].mean())**2+(Tl-Cu_SiO2_tube['Tl'].mean())**2+(Dmax-Cu_SiO2_tube['Dmax'].mean())**2+(Heating_Rate1-Cu_SiO2_tube['Heating_Rate1'].mean())**2+(Heating_Rate2-Cu_SiO2_tube['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Cu_Brass_M['Tg'].mean())**2+(Tx-Cu_Brass_M['Tx'].mean())**2+(Tl-Cu_Brass_M['Tl'].mean())**2+(Dmax-Cu_Brass_M['Dmax'].mean())**2+(Heating_Rate1-Cu_Brass_M['Heating_Rate1'].mean())**2+(Heating_Rate2-Cu_Brass_M['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Cu_CLELP['Tg'].mean())**2+(Tx-Cu_CLELP['Tx'].mean())**2+(Tl-Cu_CLELP['Tl'].mean())**2+(Dmax-Cu_CLELP['Dmax'].mean())**2+(Heating_Rate1-Cu_CLELP['Heating_Rate1'].mean())**2+(Heating_Rate2-Cu_CLELP['Heating_Rate2'].mean())**2)**0.5) 
    
    distance.append(((Tg-Cu_Cu_mold_D['Tg'].mean())**2+(Tx-Cu_Cu_mold_D['Tx'].mean())**2+(Tl-Cu_Cu_mold_D['Tl'].mean())**2+(Dmax-Cu_Cu_mold_D['Dmax'].mean())**2+(Heating_Rate1-Cu_Cu_mold_D['Heating_Rate1'].mean())**2+(Heating_Rate2-Cu_Cu_mold_D['Heating_Rate2'].mean())**2)**0.5)
    
    
    #print(distance)
    distance_1 = [x for x in distance if ~np.isnan(x)]
    
    key = min(distance_1)
    for i in range(0,11):
        if key == distance[i]:
             a = i
    print(distance_1)
    
    if (a == 0):
        a1="Cu mold"
        return(a1)
    elif(a == 1):
        a2="Cu mold S"
        return(a2)
    elif(a == 2):
        a3="Cu mold I"
        return(a3)
    elif(a == 3):
        a4="Cu mold W"
        return(a4)
    elif(a == 4):
        a5="Cu mold C"
        return(a5)
    elif(a == 5):
        a6="Cu mold HPDC"
        return(a6)
    elif(a == 6):
        a7="Melt Spin"
        return(a7)
    elif(a == 7):
        a8="SiO2 Tube"
        return(a8)
    elif(a == 8):
        a9="Brass M"
        return(a9)
    elif(a == 9):
        a10="CLELP"
        return(a10)
    elif(a  == 10):
        a11="Cu mold D"
        return(a11)

# %%
def Ca(Tg,Tx,Tl,Dmax,Heating_Rate1,Heating_Rate2):
    distance=[]
    distance_1 = []
    distance.append(((Tg-Ca_Cu_mold['Tg'].mean())**2+(Tx-Ca_Cu_mold['Tx'].mean())**2+(Tl-Ca_Cu_mold['Tl'].mean())**2+(Dmax-Ca_Cu_mold['Dmax'].mean())**2+(Heating_Rate1-Ca_Cu_mold['Heating_Rate1'].mean())**2+(Heating_Rate2-Ca_Cu_mold['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ca_Cu_mold_S['Tg'].mean())**2+(Tx-Ca_Cu_mold_S['Tx'].mean())**2+(Tl-Ca_Cu_mold_S['Tl'].mean())**2+(Dmax-Ca_Cu_mold_S['Dmax'].mean())**2+(Heating_Rate1-Ca_Cu_mold_S['Heating_Rate1'].mean())**2+(Heating_Rate2-Ca_Cu_mold_S['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ca_Cu_mold_I['Tg'].mean())**2+(Tx-Ca_Cu_mold_I['Tx'].mean())**2+(Tl-Ca_Cu_mold_I['Tl'].mean())**2+(Dmax-Ca_Cu_mold_I['Dmax'].mean())**2+(Heating_Rate1-Ca_Cu_mold_I['Heating_Rate1'].mean())**2+(Heating_Rate2-Ca_Cu_mold_I['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ca_Cu_mold_W['Tg'].mean())**2+(Tx-Ca_Cu_mold_W['Tx'].mean())**2+(Tl-Ca_Cu_mold_W['Tl'].mean())**2+(Dmax-Ca_Cu_mold_W['Dmax'].mean())**2+(Heating_Rate1-Ca_Cu_mold_W['Heating_Rate1'].mean())**2+(Heating_Rate2-Ca_Cu_mold_W['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ca_Cu_mold_C['Tg'].mean())**2+(Tx-Ca_Cu_mold_C['Tx'].mean())**2+(Tl-Ca_Cu_mold_C['Tl'].mean())**2+(Dmax-Ca_Cu_mold_C['Dmax'].mean())**2+(Heating_Rate1-Ca_Cu_mold_C['Heating_Rate1'].mean())**2+(Heating_Rate2-Ca_Cu_mold_C['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ca_Cu_mold_HPDC['Tg'].mean())**2+(Tx-Ca_Cu_mold_HPDC['Tx'].mean())**2+(Tl-Ca_Cu_mold_HPDC['Tl'].mean())**2+(Dmax-Ca_Cu_mold_HPDC['Dmax'].mean())**2+(Heating_Rate1-Ca_Cu_mold_HPDC['Heating_Rate1'].mean())**2+(Heating_Rate2-Ca_Cu_mold_HPDC['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ca_Melt_spin['Tg'].mean())**2+(Tx-Ca_Melt_spin['Tx'].mean())**2+(Tl-Ca_Melt_spin['Tl'].mean())**2+(Dmax-Ca_Melt_spin['Dmax'].mean())**2+(Heating_Rate1-Ca_Melt_spin['Heating_Rate1'].mean())**2+(Heating_Rate2-Ca_Melt_spin['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ca_SiO2_tube['Tg'].mean())**2+(Tx-Ca_SiO2_tube['Tx'].mean())**2+(Tl-Ca_SiO2_tube['Tl'].mean())**2+(Dmax-Ca_SiO2_tube['Dmax'].mean())**2+(Heating_Rate1-Ca_SiO2_tube['Heating_Rate1'].mean())**2+(Heating_Rate2-Ca_SiO2_tube['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ca_Brass_M['Tg'].mean())**2+(Tx-Ca_Brass_M['Tx'].mean())**2+(Tl-Ca_Brass_M['Tl'].mean())**2+(Dmax-Ca_Brass_M['Dmax'].mean())**2+(Heating_Rate1-Ca_Brass_M['Heating_Rate1'].mean())**2+(Heating_Rate2-Ca_Brass_M['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ca_CLELP['Tg'].mean())**2+(Tx-Ca_CLELP['Tx'].mean())**2+(Tl-Ca_CLELP['Tl'].mean())**2+(Dmax-Ca_CLELP['Dmax'].mean())**2+(Heating_Rate1-Ca_CLELP['Heating_Rate1'].mean())**2+(Heating_Rate2-Ca_CLELP['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ca_Cu_mold_D['Tg'].mean())**2+(Tx-Ca_Cu_mold_D['Tx'].mean())**2+(Tl-Ca_Cu_mold_D['Tl'].mean())**2+(Dmax-Ca_Cu_mold_D['Dmax'].mean())**2+(Heating_Rate1-Ca_Cu_mold_D['Heating_Rate1'].mean())**2+(Heating_Rate2-Ca_Cu_mold_D['Heating_Rate2'].mean())**2)**0.5)
    
    distance_1 = [x for x in distance if ~np.isnan(x)]
    key = min(distance_1)
    for i in range(0,11):
        if key == distance[i]:
            a = i
    #print(distance_1)
    if (a == 0):
        a1="Cu mold"
        return(a1)
    elif(a == 1):
        a2="Cu mold S"
        return(a2)
    elif(a == 2):
        a3="Cu mold I"
        return(a3)
    elif(a == 3):
        a4="Cu mold W"
        return(a4)
    elif(a == 4):
        a5="Cu mold C"
        return(a5)
    elif(a == 5):
        a6="Cu mold HPDC"
        return(a6)
    elif(a == 6):
        a7="Melt Spin"
        return(a7)
    elif(a == 7):
        a8="SiO2 Tube"
        return(a8)
    elif(a == 8):
        a9="Brass M"
        return(a9)
    elif(a == 9):
        a10="CLELP"
        return(a10)
    elif(a  == 10):
        a11="Cu mold D"
        return(a11)

# %%
def Mg(Tg,Tx,Tl,Dmax,Heating_Rate1,Heating_Rate2):
    distance=[]
    distance_1 = []
    distance.append(((Tg-Mg_Cu_mold['Tg'].mean())**2+(Tx-Mg_Cu_mold['Tx'].mean())**2+(Tl-Mg_Cu_mold['Tl'].mean())**2+(Dmax-Mg_Cu_mold['Dmax'].mean())**2+(Heating_Rate1-Mg_Cu_mold['Heating_Rate1'].mean())**2+(Heating_Rate2-Mg_Cu_mold['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Mg_Cu_mold_S['Tg'].mean())**2+(Tx-Mg_Cu_mold_S['Tx'].mean())**2+(Tl-Mg_Cu_mold_S['Tl'].mean())**2+(Dmax-Mg_Cu_mold_S['Dmax'].mean())**2+(Heating_Rate1-Mg_Cu_mold_S['Heating_Rate1'].mean())**2+(Heating_Rate2-Mg_Cu_mold_S['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Mg_Cu_mold_I['Tg'].mean())**2+(Tx-Mg_Cu_mold_I['Tx'].mean())**2+(Tl-Mg_Cu_mold_I['Tl'].mean())**2+(Dmax-Mg_Cu_mold_I['Dmax'].mean())**2+(Heating_Rate1-Mg_Cu_mold_I['Heating_Rate1'].mean())**2+(Heating_Rate2-Mg_Cu_mold_I['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Mg_Cu_mold_W['Tg'].mean())**2+(Tx-Mg_Cu_mold_W['Tx'].mean())**2+(Tl-Mg_Cu_mold_W['Tl'].mean())**2+(Dmax-Mg_Cu_mold_W['Dmax'].mean())**2+(Heating_Rate1-Mg_Cu_mold_W['Heating_Rate1'].mean())**2+(Heating_Rate2-Mg_Cu_mold_W['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Mg_Cu_mold_C['Tg'].mean())**2+(Tx-Mg_Cu_mold_C['Tx'].mean())**2+(Tl-Mg_Cu_mold_C['Tl'].mean())**2+(Dmax-Mg_Cu_mold_C['Dmax'].mean())**2+(Heating_Rate1-Mg_Cu_mold_C['Heating_Rate1'].mean())**2+(Heating_Rate2-Mg_Cu_mold_C['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Mg_Cu_mold_HPDC['Tg'].mean())**2+(Tx-Mg_Cu_mold_HPDC['Tx'].mean())**2+(Tl-Mg_Cu_mold_HPDC['Tl'].mean())**2+(Dmax-Mg_Cu_mold_HPDC['Dmax'].mean())**2+(Heating_Rate1-Mg_Cu_mold_HPDC['Heating_Rate1'].mean())**2+(Heating_Rate2-Mg_Cu_mold_HPDC['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Mg_Melt_spin['Tg'].mean())**2+(Tx-Mg_Melt_spin['Tx'].mean())**2+(Tl-Mg_Melt_spin['Tl'].mean())**2+(Dmax-Mg_Melt_spin['Dmax'].mean())**2+(Heating_Rate1-Mg_Melt_spin['Heating_Rate1'].mean())**2+(Heating_Rate2-Mg_Melt_spin['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Mg_SiO2_tube['Tg'].mean())**2+(Tx-Mg_SiO2_tube['Tx'].mean())**2+(Tl-Mg_SiO2_tube['Tl'].mean())**2+(Dmax-Mg_SiO2_tube['Dmax'].mean())**2+(Heating_Rate1-Mg_SiO2_tube['Heating_Rate1'].mean())**2+(Heating_Rate2-Mg_SiO2_tube['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Mg_Brass_M['Tg'].mean())**2+(Tx-Mg_Brass_M['Tx'].mean())**2+(Tl-Mg_Brass_M['Tl'].mean())**2+(Dmax-Mg_Brass_M['Dmax'].mean())**2+(Heating_Rate1-Mg_Brass_M['Heating_Rate1'].mean())**2+(Heating_Rate2-Mg_Brass_M['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Mg_CLELP['Tg'].mean())**2+(Tx-Mg_CLELP['Tx'].mean())**2+(Tl-Mg_CLELP['Tl'].mean())**2+(Dmax-Mg_CLELP['Dmax'].mean())**2+(Heating_Rate1-Mg_CLELP['Heating_Rate1'].mean())**2+(Heating_Rate2-Mg_CLELP['Heating_Rate2'].mean())**2)**0.5) 
    
    distance.append(((Tg-Mg_Cu_mold_D['Tg'].mean())**2+(Tx-Mg_Cu_mold_D['Tx'].mean())**2+(Tl-Mg_Cu_mold_D['Tl'].mean())**2+(Dmax-Mg_Cu_mold_D['Dmax'].mean())**2+(Heating_Rate1-Mg_Cu_mold_D['Heating_Rate1'].mean())**2+(Heating_Rate2-Mg_Cu_mold_D['Heating_Rate2'].mean())**2)**0.5)
    

    
    distance_1 = [x for x in distance if ~np.isnan(x)]
    key = min(distance_1)
    for i in range(0,11):
        if key == distance[i]:
            a = i
    #print(distance_1)
    if (a == 0):
        a1="Cu mold"
        return(a1)
    elif(a == 1):
        a2="Cu mold S"
        return(a2)
    elif(a == 2):
        a3="Cu mold I"
        return(a3)
    elif(a == 3):
        a4="Cu mold W"
        return(a4)
    elif(a == 4):
        a5="Cu mold C"
        return(a5)
    elif(a == 5):
        a6="Cu mold HPDC"
        return(a6)
    elif(a == 6):
        a7="Melt Spin"
        return(a7)
    elif(a == 7):
        a8="SiO2 Tube"
        return(a8)
    elif(a == 8):
        a9="Brass M"
        return(a9)
    elif(a == 9):
        a10="CLELP"
        return(a10)
    elif(a  == 10):
        a11="Cu mold D"
        return(a11)

# %%
def La(Tg,Tx,Tl,Dmax,Heating_Rate1,Heating_Rate2):
    distance=[]
    distance_1 = []
    distance.append(((Tg-La_Cu_mold['Tg'].mean())**2+(Tx-La_Cu_mold['Tx'].mean())**2+(Tl-La_Cu_mold['Tl'].mean())**2+(Dmax-La_Cu_mold['Dmax'].mean())**2+(Heating_Rate1-La_Cu_mold['Heating_Rate1'].mean())**2+(Heating_Rate2-La_Cu_mold['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-La_Cu_mold_S['Tg'].mean())**2+(Tx-La_Cu_mold_S['Tx'].mean())**2+(Tl-La_Cu_mold_S['Tl'].mean())**2+(Dmax-La_Cu_mold_S['Dmax'].mean())**2+(Heating_Rate1-La_Cu_mold_S['Heating_Rate1'].mean())**2+(Heating_Rate2-La_Cu_mold_S['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-La_Cu_mold_I['Tg'].mean())**2+(Tx-La_Cu_mold_I['Tx'].mean())**2+(Tl-La_Cu_mold_I['Tl'].mean())**2+(Dmax-La_Cu_mold_I['Dmax'].mean())**2+(Heating_Rate1-La_Cu_mold_I['Heating_Rate1'].mean())**2+(Heating_Rate2-La_Cu_mold_I['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-La_Cu_mold_W['Tg'].mean())**2+(Tx-La_Cu_mold_W['Tx'].mean())**2+(Tl-La_Cu_mold_W['Tl'].mean())**2+(Dmax-La_Cu_mold_W['Dmax'].mean())**2+(Heating_Rate1-La_Cu_mold_W['Heating_Rate1'].mean())**2+(Heating_Rate2-La_Cu_mold_W['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-La_Cu_mold_C['Tg'].mean())**2+(Tx-La_Cu_mold_C['Tx'].mean())**2+(Tl-La_Cu_mold_C['Tl'].mean())**2+(Dmax-La_Cu_mold_C['Dmax'].mean())**2+(Heating_Rate1-La_Cu_mold_C['Heating_Rate1'].mean())**2+(Heating_Rate2-La_Cu_mold_C['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-La_Cu_mold_HPDC['Tg'].mean())**2+(Tx-La_Cu_mold_HPDC['Tx'].mean())**2+(Tl-La_Cu_mold_HPDC['Tl'].mean())**2+(Dmax-La_Cu_mold_HPDC['Dmax'].mean())**2+(Heating_Rate1-La_Cu_mold_HPDC['Heating_Rate1'].mean())**2+(Heating_Rate2-La_Cu_mold_HPDC['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-La_Melt_spin['Tg'].mean())**2+(Tx-La_Melt_spin['Tx'].mean())**2+(Tl-La_Melt_spin['Tl'].mean())**2+(Dmax-La_Melt_spin['Dmax'].mean())**2+(Heating_Rate1-La_Melt_spin['Heating_Rate1'].mean())**2+(Heating_Rate2-La_Melt_spin['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-La_SiO2_tube['Tg'].mean())**2+(Tx-La_SiO2_tube['Tx'].mean())**2+(Tl-La_SiO2_tube['Tl'].mean())**2+(Dmax-La_SiO2_tube['Dmax'].mean())**2+(Heating_Rate1-La_SiO2_tube['Heating_Rate1'].mean())**2+(Heating_Rate2-La_SiO2_tube['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-La_Brass_M['Tg'].mean())**2+(Tx-La_Brass_M['Tx'].mean())**2+(Tl-La_Brass_M['Tl'].mean())**2+(Dmax-La_Brass_M['Dmax'].mean())**2+(Heating_Rate1-La_Brass_M['Heating_Rate1'].mean())**2+(Heating_Rate2-La_Brass_M['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-La_CLELP['Tg'].mean())**2+(Tx-La_CLELP['Tx'].mean())**2+(Tl-La_CLELP['Tl'].mean())**2+(Dmax-La_CLELP['Dmax'].mean())**2+(Heating_Rate1-La_CLELP['Heating_Rate1'].mean())**2+(Heating_Rate2-La_CLELP['Heating_Rate2'].mean())**2)**0.5) 
    
    distance.append(((Tg-La_Cu_mold_D['Tg'].mean())**2+(Tx-La_Cu_mold_D['Tx'].mean())**2+(Tl-La_Cu_mold_D['Tl'].mean())**2+(Dmax-La_Cu_mold_D['Dmax'].mean())**2+(Heating_Rate1-La_Cu_mold_D['Heating_Rate1'].mean())**2+(Heating_Rate2-La_Cu_mold_D['Heating_Rate2'].mean())**2)**0.5)
    


    #print(distance)
    distance_1 = [x for x in distance if ~np.isnan(x)]
    key = min(distance_1)
    for i in range(0,11):
        if key == distance[i]:
            a = i
    #print(distance_1)
    if (a == 0):
        a1="Cu mold"
        return(a1)
    elif(a == 1):
        a2="Cu mold S"
        return(a2)
    elif(a == 2):
        a3="Cu mold I"
        return(a3)
    elif(a == 3):
        a4="Cu mold W"
        return(a4)
    elif(a == 4):
        a5="Cu mold C"
        return(a5)
    elif(a == 5):
        a6="Cu mold HPDC"
        return(a6)
    elif(a == 6):
        a7="Melt Spin"
        return(a7)
    elif(a == 7):
        a8="SiO2 Tube"
        return(a8)
    elif(a == 8):
        a9="Brass M"
        return(a9)
    elif(a == 9):
        a10="CLELP"
        return(a10)
    elif(a  == 10):
        a11="Cu mold D"
        return(a11)

# %%
def Pd(Tg,Tx,Tl,Dmax,Heating_Rate1,Heating_Rate2):
    distance=[]
    distance_1 = []
    distance.append(((Tg-Pd_Cu_mold['Tg'].mean())**2+(Tx-Pd_Cu_mold['Tx'].mean())**2+(Tl-Pd_Cu_mold['Tl'].mean())**2+(Dmax-Pd_Cu_mold['Dmax'].mean())**2+(Heating_Rate1-Pd_Cu_mold['Heating_Rate1'].mean())**2+(Heating_Rate2-Pd_Cu_mold['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Pd_Cu_mold_S['Tg'].mean())**2+(Tx-Pd_Cu_mold_S['Tx'].mean())**2+(Tl-Pd_Cu_mold_S['Tl'].mean())**2+(Dmax-Pd_Cu_mold_S['Dmax'].mean())**2+(Heating_Rate1-Pd_Cu_mold_S['Heating_Rate1'].mean())**2+(Heating_Rate2-Pd_Cu_mold_S['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Pd_Cu_mold_I['Tg'].mean())**2+(Tx-Pd_Cu_mold_I['Tx'].mean())**2+(Tl-Pd_Cu_mold_I['Tl'].mean())**2+(Dmax-Pd_Cu_mold_I['Dmax'].mean())**2+(Heating_Rate1-Pd_Cu_mold_I['Heating_Rate1'].mean())**2+(Heating_Rate2-Pd_Cu_mold_I['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Pd_Cu_mold_W['Tg'].mean())**2+(Tx-Pd_Cu_mold_W['Tx'].mean())**2+(Tl-Pd_Cu_mold_W['Tl'].mean())**2+(Dmax-Pd_Cu_mold_W['Dmax'].mean())**2+(Heating_Rate1-Pd_Cu_mold_W['Heating_Rate1'].mean())**2+(Heating_Rate2-Pd_Cu_mold_W['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Pd_Cu_mold_C['Tg'].mean())**2+(Tx-Pd_Cu_mold_C['Tx'].mean())**2+(Tl-Pd_Cu_mold_C['Tl'].mean())**2+(Dmax-Pd_Cu_mold_C['Dmax'].mean())**2+(Heating_Rate1-Pd_Cu_mold_C['Heating_Rate1'].mean())**2+(Heating_Rate2-Pd_Cu_mold_C['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Pd_Cu_mold_HPDC['Tg'].mean())**2+(Tx-Pd_Cu_mold_HPDC['Tx'].mean())**2+(Tl-Pd_Cu_mold_HPDC['Tl'].mean())**2+(Dmax-Pd_Cu_mold_HPDC['Dmax'].mean())**2+(Heating_Rate1-Pd_Cu_mold_HPDC['Heating_Rate1'].mean())**2+(Heating_Rate2-Pd_Cu_mold_HPDC['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Pd_Melt_spin['Tg'].mean())**2+(Tx-Pd_Melt_spin['Tx'].mean())**2+(Tl-Pd_Melt_spin['Tl'].mean())**2+(Dmax-Pd_Melt_spin['Dmax'].mean())**2+(Heating_Rate1-Pd_Melt_spin['Heating_Rate1'].mean())**2+(Heating_Rate2-Pd_Melt_spin['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Pd_SiO2_tube['Tg'].mean())**2+(Tx-Pd_SiO2_tube['Tx'].mean())**2+(Tl-Pd_SiO2_tube['Tl'].mean())**2+(Dmax-Pd_SiO2_tube['Dmax'].mean())**2+(Heating_Rate1-Pd_SiO2_tube['Heating_Rate1'].mean())**2+(Heating_Rate2-Pd_SiO2_tube['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Pd_Brass_M['Tg'].mean())**2+(Tx-Pd_Brass_M['Tx'].mean())**2+(Tl-Pd_Brass_M['Tl'].mean())**2+(Dmax-Pd_Brass_M['Dmax'].mean())**2+(Heating_Rate1-Pd_Brass_M['Heating_Rate1'].mean())**2+(Heating_Rate2-Pd_Brass_M['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Pd_CLELP['Tg'].mean())**2+(Tx-Pd_CLELP['Tx'].mean())**2+(Tl-Pd_CLELP['Tl'].mean())**2+(Dmax-Pd_CLELP['Dmax'].mean())**2+(Heating_Rate1-Pd_CLELP['Heating_Rate1'].mean())**2+(Heating_Rate2-Pd_CLELP['Heating_Rate2'].mean())**2)**0.5) 
    
    distance.append(((Tg-Pd_Cu_mold_D['Tg'].mean())**2+(Tx-Pd_Cu_mold_D['Tx'].mean())**2+(Tl-Pd_Cu_mold_D['Tl'].mean())**2+(Dmax-Pd_Cu_mold_D['Dmax'].mean())**2+(Heating_Rate1-Pd_Cu_mold_D['Heating_Rate1'].mean())**2+(Heating_Rate2-Pd_Cu_mold_D['Heating_Rate2'].mean())**2)**0.5)
    

    
    distance_1 = [x for x in distance if ~np.isnan(x)]
    key = min(distance_1)
    for i in range(0,11):
        if key == distance[i]:
            a = i
    #print(distance_1)
    if (a == 0):
        a1="Cu mold"
        return(a1)
    elif(a == 1):
        a2="Cu mold S"
        return(a2)
    elif(a == 2):
        a3="Cu mold I"
        return(a3)
    elif(a == 3):
        a4="Cu mold W"
        return(a4)
    elif(a == 4):
        a5="Cu mold C"
        return(a5)
    elif(a == 5):
        a6="Cu mold HPDC"
        return(a6)
    elif(a == 6):
        a7="Melt Spin"
        return(a7)
    elif(a == 7):
        a8="SiO2 Tube"
        return(a8)
    elif(a == 8):
        a9="Brass M"
        return(a9)
    elif(a == 9):
        a10="CLELP"
        return(a10)
    elif(a  == 10):
        a11="Cu mold D"
        return(a11)

# %%
def Ti(Tg,Tx,Tl,Dmax,Heating_Rate1,Heating_Rate2):
    distance=[]
    distance_1 = []
    distance.append(((Tg-Ti_Cu_mold['Tg'].mean())**2+(Tx-Ti_Cu_mold['Tx'].mean())**2+(Tl-Ti_Cu_mold['Tl'].mean())**2+(Dmax-Ti_Cu_mold['Dmax'].mean())**2+(Heating_Rate1-Ti_Cu_mold['Heating_Rate1'].mean())**2+(Heating_Rate2-Ti_Cu_mold['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ti_Cu_mold_S['Tg'].mean())**2+(Tx-Ti_Cu_mold_S['Tx'].mean())**2+(Tl-Ti_Cu_mold_S['Tl'].mean())**2+(Dmax-Ti_Cu_mold_S['Dmax'].mean())**2+(Heating_Rate1-Ti_Cu_mold_S['Heating_Rate1'].mean())**2+(Heating_Rate2-Ti_Cu_mold_S['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ti_Cu_mold_I['Tg'].mean())**2+(Tx-Ti_Cu_mold_I['Tx'].mean())**2+(Tl-Ti_Cu_mold_I['Tl'].mean())**2+(Dmax-Ti_Cu_mold_I['Dmax'].mean())**2+(Heating_Rate1-Ti_Cu_mold_I['Heating_Rate1'].mean())**2+(Heating_Rate2-Ti_Cu_mold_I['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ti_Cu_mold_W['Tg'].mean())**2+(Tx-Ti_Cu_mold_W['Tx'].mean())**2+(Tl-Ti_Cu_mold_W['Tl'].mean())**2+(Dmax-Ti_Cu_mold_W['Dmax'].mean())**2+(Heating_Rate1-Ti_Cu_mold_W['Heating_Rate1'].mean())**2+(Heating_Rate2-Ti_Cu_mold_W['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ti_Cu_mold_C['Tg'].mean())**2+(Tx-Ti_Cu_mold_C['Tx'].mean())**2+(Tl-Ti_Cu_mold_C['Tl'].mean())**2+(Dmax-Ti_Cu_mold_C['Dmax'].mean())**2+(Heating_Rate1-Ti_Cu_mold_C['Heating_Rate1'].mean())**2+(Heating_Rate2-Ti_Cu_mold_C['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ti_Cu_mold_HPDC['Tg'].mean())**2+(Tx-Ti_Cu_mold_HPDC['Tx'].mean())**2+(Tl-Ti_Cu_mold_HPDC['Tl'].mean())**2+(Dmax-Ti_Cu_mold_HPDC['Dmax'].mean())**2+(Heating_Rate1-Ti_Cu_mold_HPDC['Heating_Rate1'].mean())**2+(Heating_Rate2-Ti_Cu_mold_HPDC['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ti_Melt_spin['Tg'].mean())**2+(Tx-Ti_Melt_spin['Tx'].mean())**2+(Tl-Ti_Melt_spin['Tl'].mean())**2+(Dmax-Ti_Melt_spin['Dmax'].mean())**2+(Heating_Rate1-Ti_Melt_spin['Heating_Rate1'].mean())**2+(Heating_Rate2-Ti_Melt_spin['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ti_SiO2_tube['Tg'].mean())**2+(Tx-Ti_SiO2_tube['Tx'].mean())**2+(Tl-Ti_SiO2_tube['Tl'].mean())**2+(Dmax-Ti_SiO2_tube['Dmax'].mean())**2+(Heating_Rate1-Ti_SiO2_tube['Heating_Rate1'].mean())**2+(Heating_Rate2-Ti_SiO2_tube['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ti_Brass_M['Tg'].mean())**2+(Tx-Ti_Brass_M['Tx'].mean())**2+(Tl-Ti_Brass_M['Tl'].mean())**2+(Dmax-Ti_Brass_M['Dmax'].mean())**2+(Heating_Rate1-Ti_Brass_M['Heating_Rate1'].mean())**2+(Heating_Rate2-Ti_Brass_M['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ti_CLELP['Tg'].mean())**2+(Tx-Ti_CLELP['Tx'].mean())**2+(Tl-Ti_CLELP['Tl'].mean())**2+(Dmax-Ti_CLELP['Dmax'].mean())**2+(Heating_Rate1-Ti_CLELP['Heating_Rate1'].mean())**2+(Heating_Rate2-Ti_CLELP['Heating_Rate2'].mean())**2)**0.5) 
    
    distance.append(((Tg-Ti_Cu_mold_D['Tg'].mean())**2+(Tx-Ti_Cu_mold_D['Tx'].mean())**2+(Tl-Ti_Cu_mold_D['Tl'].mean())**2+(Dmax-Ti_Cu_mold_D['Dmax'].mean())**2+(Heating_Rate1-Ti_Cu_mold_D['Heating_Rate1'].mean())**2+(Heating_Rate2-Ti_Cu_mold_D['Heating_Rate2'].mean())**2)**0.5)
     
    
    distance_1 = [x for x in distance if ~np.isnan(x)]
    key = min(distance_1)
    for i in range(0,11):
        if key == distance[i]:
            a = i
    #print(distance_1)
    if (a == 0):
        a1="Cu mold"
        return(a1)
    elif(a == 1):
        a2="Cu mold S"
        return(a2)
    elif(a == 2):
        a3="Cu mold I"
        return(a3)
    elif(a == 3):
        a4="Cu mold W"
        return(a4)
    elif(a == 4):
        a5="Cu mold C"
        return(a5)
    elif(a == 5):
        a6="Cu mold HPDC"
        return(a6)
    elif(a == 6):
        a7="Melt Spin"
        return(a7)
    elif(a == 7):
        a8="SiO2 Tube"
        return(a8)
    elif(a == 8):
        a9="Brass M"
        return(a9)
    elif(a == 9):
        a10="CLELP"
        return(a10)
    elif(a  == 10):
        a11="Cu mold D"
        return(a11)

# %%
def Co(Tg,Tx,Tl,Dmax,Heating_Rate1,Heating_Rate2):
    distance=[]
    distance_1 = []
    distance.append(((Tg-Co_Cu_mold['Tg'].mean())**2+(Tx-Co_Cu_mold['Tx'].mean())**2+(Tl-Co_Cu_mold['Tl'].mean())**2+(Dmax-Co_Cu_mold['Dmax'].mean())**2+(Heating_Rate1-Co_Cu_mold['Heating_Rate1'].mean())**2+(Heating_Rate2-Co_Cu_mold['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Co_Cu_mold_S['Tg'].mean())**2+(Tx-Co_Cu_mold_S['Tx'].mean())**2+(Tl-Co_Cu_mold_S['Tl'].mean())**2+(Dmax-Co_Cu_mold_S['Dmax'].mean())**2+(Heating_Rate1-Co_Cu_mold_S['Heating_Rate1'].mean())**2+(Heating_Rate2-Co_Cu_mold_S['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Co_Cu_mold_I['Tg'].mean())**2+(Tx-Co_Cu_mold_I['Tx'].mean())**2+(Tl-Co_Cu_mold_I['Tl'].mean())**2+(Dmax-Co_Cu_mold_I['Dmax'].mean())**2+(Heating_Rate1-Co_Cu_mold_I['Heating_Rate1'].mean())**2+(Heating_Rate2-Co_Cu_mold_I['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Co_Cu_mold_W['Tg'].mean())**2+(Tx-Co_Cu_mold_W['Tx'].mean())**2+(Tl-Co_Cu_mold_W['Tl'].mean())**2+(Dmax-Co_Cu_mold_W['Dmax'].mean())**2+(Heating_Rate1-Co_Cu_mold_W['Heating_Rate1'].mean())**2+(Heating_Rate2-Co_Cu_mold_W['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Co_Cu_mold_C['Tg'].mean())**2+(Tx-Co_Cu_mold_C['Tx'].mean())**2+(Tl-Co_Cu_mold_C['Tl'].mean())**2+(Dmax-Co_Cu_mold_C['Dmax'].mean())**2+(Heating_Rate1-Co_Cu_mold_C['Heating_Rate1'].mean())**2+(Heating_Rate2-Co_Cu_mold_C['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Co_Cu_mold_HPDC['Tg'].mean())**2+(Tx-Co_Cu_mold_HPDC['Tx'].mean())**2+(Tl-Co_Cu_mold_HPDC['Tl'].mean())**2+(Dmax-Co_Cu_mold_HPDC['Dmax'].mean())**2+(Heating_Rate1-Co_Cu_mold_HPDC['Heating_Rate1'].mean())**2+(Heating_Rate2-Co_Cu_mold_HPDC['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Co_Melt_spin['Tg'].mean())**2+(Tx-Co_Melt_spin['Tx'].mean())**2+(Tl-Co_Melt_spin['Tl'].mean())**2+(Dmax-Co_Melt_spin['Dmax'].mean())**2+(Heating_Rate1-Co_Melt_spin['Heating_Rate1'].mean())**2+(Heating_Rate2-Co_Melt_spin['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Co_SiO2_tube['Tg'].mean())**2+(Tx-Co_SiO2_tube['Tx'].mean())**2+(Tl-Co_SiO2_tube['Tl'].mean())**2+(Dmax-Co_SiO2_tube['Dmax'].mean())**2+(Heating_Rate1-Co_SiO2_tube['Heating_Rate1'].mean())**2+(Heating_Rate2-Co_SiO2_tube['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Co_Brass_M['Tg'].mean())**2+(Tx-Co_Brass_M['Tx'].mean())**2+(Tl-Co_Brass_M['Tl'].mean())**2+(Dmax-Co_Brass_M['Dmax'].mean())**2+(Heating_Rate1-Co_Brass_M['Heating_Rate1'].mean())**2+(Heating_Rate2-Co_Brass_M['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Co_CLELP['Tg'].mean())**2+(Tx-Co_CLELP['Tx'].mean())**2+(Tl-Co_CLELP['Tl'].mean())**2+(Dmax-Co_CLELP['Dmax'].mean())**2+(Heating_Rate1-Co_CLELP['Heating_Rate1'].mean())**2+(Heating_Rate2-Co_CLELP['Heating_Rate2'].mean())**2)**0.5) 
    
    distance.append(((Tg-Co_Cu_mold_D['Tg'].mean())**2+(Tx-Co_Cu_mold_D['Tx'].mean())**2+(Tl-Co_Cu_mold_D['Tl'].mean())**2+(Dmax-Co_Cu_mold_D['Dmax'].mean())**2+(Heating_Rate1-Co_Cu_mold_D['Heating_Rate1'].mean())**2+(Heating_Rate2-Co_Cu_mold_D['Heating_Rate2'].mean())**2)**0.5)
    


    distance_1 = [x for x in distance if ~np.isnan(x)]
    key = min(distance_1)
    for i in range(0,11):
        if key == distance[i]:
            a = i
    #print(distance_1)
    if (a == 0):
        a1="Cu mold"
        return(a1)
    elif(a == 1):
        a2="Cu mold S"
        return(a2)
    elif(a == 2):
        a3="Cu mold I"
        return(a3)
    elif(a == 3):
        a4="Cu mold W"
        return(a4)
    elif(a == 4):
        a5="Cu mold C"
        return(a5)
    elif(a == 5):
        a6="Cu mold HPDC"
        return(a6)
    elif(a == 6):
        a7="Melt Spin"
        return(a7)
    elif(a == 7):
        a8="SiO2 Tube"
        return(a8)
    elif(a == 8):
        a9="Brass M"
        return(a9)
    elif(a == 9):
        a10="CLELP"
        return(a10)
    elif(a  == 10):
        a11="Cu mold D"
        return(a11)

# %%
def Au(Tg,Tx,Tl,Dmax,Heating_Rate1,Heating_Rate2):
    distance=[]
    distance_1 = []
    distance.append(((Tg-Au_Cu_mold['Tg'].mean())**2+(Tx-Au_Cu_mold['Tx'].mean())**2+(Tl-Au_Cu_mold['Tl'].mean())**2+(Dmax-Au_Cu_mold['Dmax'].mean())**2+(Heating_Rate1-Au_Cu_mold['Heating_Rate1'].mean())**2+(Heating_Rate2-Au_Cu_mold['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Au_Cu_mold_S['Tg'].mean())**2+(Tx-Au_Cu_mold_S['Tx'].mean())**2+(Tl-Au_Cu_mold_S['Tl'].mean())**2+(Dmax-Au_Cu_mold_S['Dmax'].mean())**2+(Heating_Rate1-Au_Cu_mold_S['Heating_Rate1'].mean())**2+(Heating_Rate2-Au_Cu_mold_S['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Au_Cu_mold_I['Tg'].mean())**2+(Tx-Au_Cu_mold_I['Tx'].mean())**2+(Tl-Au_Cu_mold_I['Tl'].mean())**2+(Dmax-Au_Cu_mold_I['Dmax'].mean())**2+(Heating_Rate1-Au_Cu_mold_I['Heating_Rate1'].mean())**2+(Heating_Rate2-Au_Cu_mold_I['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Au_Cu_mold_W['Tg'].mean())**2+(Tx-Au_Cu_mold_W['Tx'].mean())**2+(Tl-Au_Cu_mold_W['Tl'].mean())**2+(Dmax-Au_Cu_mold_W['Dmax'].mean())**2+(Heating_Rate1-Au_Cu_mold_W['Heating_Rate1'].mean())**2+(Heating_Rate2-Au_Cu_mold_W['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Au_Cu_mold_C['Tg'].mean())**2+(Tx-Au_Cu_mold_C['Tx'].mean())**2+(Tl-Au_Cu_mold_C['Tl'].mean())**2+(Dmax-Au_Cu_mold_C['Dmax'].mean())**2+(Heating_Rate1-Au_Cu_mold_C['Heating_Rate1'].mean())**2+(Heating_Rate2-Au_Cu_mold_C['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Au_Cu_mold_HPDC['Tg'].mean())**2+(Tx-Au_Cu_mold_HPDC['Tx'].mean())**2+(Tl-Au_Cu_mold_HPDC['Tl'].mean())**2+(Dmax-Au_Cu_mold_HPDC['Dmax'].mean())**2+(Heating_Rate1-Au_Cu_mold_HPDC['Heating_Rate1'].mean())**2+(Heating_Rate2-Au_Cu_mold_HPDC['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Au_Melt_spin['Tg'].mean())**2+(Tx-Au_Melt_spin['Tx'].mean())**2+(Tl-Au_Melt_spin['Tl'].mean())**2+(Dmax-Au_Melt_spin['Dmax'].mean())**2+(Heating_Rate1-Au_Melt_spin['Heating_Rate1'].mean())**2+(Heating_Rate2-Au_Melt_spin['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Au_SiO2_tube['Tg'].mean())**2+(Tx-Au_SiO2_tube['Tx'].mean())**2+(Tl-Au_SiO2_tube['Tl'].mean())**2+(Dmax-Au_SiO2_tube['Dmax'].mean())**2+(Heating_Rate1-Au_SiO2_tube['Heating_Rate1'].mean())**2+(Heating_Rate2-Au_SiO2_tube['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Au_Brass_M['Tg'].mean())**2+(Tx-Au_Brass_M['Tx'].mean())**2+(Tl-Au_Brass_M['Tl'].mean())**2+(Dmax-Au_Brass_M['Dmax'].mean())**2+(Heating_Rate1-Au_Brass_M['Heating_Rate1'].mean())**2+(Heating_Rate2-Au_Brass_M['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Au_CLELP['Tg'].mean())**2+(Tx-Au_CLELP['Tx'].mean())**2+(Tl-Au_CLELP['Tl'].mean())**2+(Dmax-Au_CLELP['Dmax'].mean())**2+(Heating_Rate1-Au_CLELP['Heating_Rate1'].mean())**2+(Heating_Rate2-Au_CLELP['Heating_Rate2'].mean())**2)**0.5) 
    
    distance.append(((Tg-Au_Cu_mold_D['Tg'].mean())**2+(Tx-Au_Cu_mold_D['Tx'].mean())**2+(Tl-Au_Cu_mold_D['Tl'].mean())**2+(Dmax-Au_Cu_mold_D['Dmax'].mean())**2+(Heating_Rate1-Au_Cu_mold_D['Heating_Rate1'].mean())**2+(Heating_Rate2-Au_Cu_mold_D['Heating_Rate2'].mean())**2)**0.5)
    


    
    #print(distance[5])
    distance_1 = [x for x in distance if ~np.isnan(x)]
    key = min(distance_1)
    for i in range(0,11):
        if key == distance[i]:
            a = i
    if (a == 0):
        a1="Cu mold"
        return(a1)
    elif(a == 1):
        a2="Cu mold S"
        return(a2)
    elif(a == 2):
        a3="Cu mold I"
        return(a3)
    elif(a == 3):
        a4="Cu mold W"
        return(a4)
    elif(a == 4):
        a5="Cu mold C"
        return(a5)
    elif(a == 5):
        a6="Cu mold HPDC"
        return(a6)
    elif(a == 6):
        a7="Melt Spin"
        return(a7)
    elif(a == 7):
        a8="SiO2 Tube"
        return(a8)
    elif(a == 8):
        a9="Brass M"
        return(a9)
    elif(a == 9):
        a10="CLELP"
        return(a10)
    elif(a  == 10):
        a11="Cu mold D"
        return(a11)

# %%
def Ag(Tg,Tx,Tl,Dmax,Heating_Rate1,Heating_Rate2):
    distance=[]
    distance_1 = []
    distance.append(((Tg-Ag_Cu_mold['Tg'].mean())**2+(Tx-Ag_Cu_mold['Tx'].mean())**2+(Tl-Ag_Cu_mold['Tl'].mean())**2+(Dmax-Ag_Cu_mold['Dmax'].mean())**2+(Heating_Rate1-Ag_Cu_mold['Heating_Rate1'].mean())**2+(Heating_Rate2-Ag_Cu_mold['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ag_Cu_mold_S['Tg'].mean())**2+(Tx-Ag_Cu_mold_S['Tx'].mean())**2+(Tl-Ag_Cu_mold_S['Tl'].mean())**2+(Dmax-Ag_Cu_mold_S['Dmax'].mean())**2+(Heating_Rate1-Ag_Cu_mold_S['Heating_Rate1'].mean())**2+(Heating_Rate2-Ag_Cu_mold_S['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ag_Cu_mold_I['Tg'].mean())**2+(Tx-Ag_Cu_mold_I['Tx'].mean())**2+(Tl-Ag_Cu_mold_I['Tl'].mean())**2+(Dmax-Ag_Cu_mold_I['Dmax'].mean())**2+(Heating_Rate1-Ag_Cu_mold_I['Heating_Rate1'].mean())**2+(Heating_Rate2-Ag_Cu_mold_I['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ag_Cu_mold_W['Tg'].mean())**2+(Tx-Ag_Cu_mold_W['Tx'].mean())**2+(Tl-Ag_Cu_mold_W['Tl'].mean())**2+(Dmax-Ag_Cu_mold_W['Dmax'].mean())**2+(Heating_Rate1-Ag_Cu_mold_W['Heating_Rate1'].mean())**2+(Heating_Rate2-Ag_Cu_mold_W['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ag_Cu_mold_C['Tg'].mean())**2+(Tx-Ag_Cu_mold_C['Tx'].mean())**2+(Tl-Ag_Cu_mold_C['Tl'].mean())**2+(Dmax-Ag_Cu_mold_C['Dmax'].mean())**2+(Heating_Rate1-Ag_Cu_mold_C['Heating_Rate1'].mean())**2+(Heating_Rate2-Ag_Cu_mold_C['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ag_Cu_mold_HPDC['Tg'].mean())**2+(Tx-Ag_Cu_mold_HPDC['Tx'].mean())**2+(Tl-Ag_Cu_mold_HPDC['Tl'].mean())**2+(Dmax-Ag_Cu_mold_HPDC['Dmax'].mean())**2+(Heating_Rate1-Ag_Cu_mold_HPDC['Heating_Rate1'].mean())**2+(Heating_Rate2-Ag_Cu_mold_HPDC['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ag_Melt_spin['Tg'].mean())**2+(Tx-Ag_Melt_spin['Tx'].mean())**2+(Tl-Ag_Melt_spin['Tl'].mean())**2+(Dmax-Ag_Melt_spin['Dmax'].mean())**2+(Heating_Rate1-Ag_Melt_spin['Heating_Rate1'].mean())**2+(Heating_Rate2-Ag_Melt_spin['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ag_SiO2_tube['Tg'].mean())**2+(Tx-Ag_SiO2_tube['Tx'].mean())**2+(Tl-Ag_SiO2_tube['Tl'].mean())**2+(Dmax-Ag_SiO2_tube['Dmax'].mean())**2+(Heating_Rate1-Ag_SiO2_tube['Heating_Rate1'].mean())**2+(Heating_Rate2-Ag_SiO2_tube['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ag_Brass_M['Tg'].mean())**2+(Tx-Ag_Brass_M['Tx'].mean())**2+(Tl-Ag_Brass_M['Tl'].mean())**2+(Dmax-Ag_Brass_M['Dmax'].mean())**2+(Heating_Rate1-Ag_Brass_M['Heating_Rate1'].mean())**2+(Heating_Rate2-Ag_Brass_M['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ag_CLELP['Tg'].mean())**2+(Tx-Ag_CLELP['Tx'].mean())**2+(Tl-Ag_CLELP['Tl'].mean())**2+(Dmax-Ag_CLELP['Dmax'].mean())**2+(Heating_Rate1-Ag_CLELP['Heating_Rate1'].mean())**2+(Heating_Rate2-Ag_CLELP['Heating_Rate2'].mean())**2)**0.5) 
    
    distance.append(((Tg-Ag_Cu_mold_D['Tg'].mean())**2+(Tx-Ag_Cu_mold_D['Tx'].mean())**2+(Tl-Ag_Cu_mold_D['Tl'].mean())**2+(Dmax-Ag_Cu_mold_D['Dmax'].mean())**2+(Heating_Rate1-Ag_Cu_mold_D['Heating_Rate1'].mean())**2+(Heating_Rate2-Ag_Cu_mold_D['Heating_Rate2'].mean())**2)**0.5)
    


    
    print(distance)
    distance_1 = [x for x in distance if ~np.isnan(x)]
    key = min(distance_1)
    for i in range(0,11):
        if key == distance[i]:
            a = i
    #print(distance_1)
    if (a == 0):
        a1="Cu mold"
        return(a1)
    elif(a == 1):
        a2="Cu mold S"
        return(a2)
    elif(a == 2):
        a3="Cu mold I"
        return(a3)
    elif(a == 3):
        a4="Cu mold W"
        return(a4)
    elif(a == 4):
        a5="Cu mold C"
        return(a5)
    elif(a == 5):
        a6="Cu mold HPDC"
        return(a6)
    elif(a == 6):
        a7="Melt Spin"
        return(a7)
    elif(a == 7):
        a8="SiO2 Tube"
        return(a8)
    elif(a == 8):
        a9="Brass M"
        return(a9)
    elif(a == 9):
        a10="CLELP"
        return(a10)
    elif(a  == 10):
        a11="Cu mold D"
        return(a11)

# %%
def Hf(Tg,Tx,Tl,Dmax,Heating_Rate1,Heating_Rate2):
    distance=[]
    distance_1 = []
    distance.append(((Tg-Hf_Cu_mold['Tg'].mean())**2+(Tx-Hf_Cu_mold['Tx'].mean())**2+(Tl-Hf_Cu_mold['Tl'].mean())**2+(Dmax-Hf_Cu_mold['Dmax'].mean())**2+(Heating_Rate1-Hf_Cu_mold['Heating_Rate1'].mean())**2+(Heating_Rate2-Hf_Cu_mold['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Hf_Cu_mold_S['Tg'].mean())**2+(Tx-Hf_Cu_mold_S['Tx'].mean())**2+(Tl-Hf_Cu_mold_S['Tl'].mean())**2+(Dmax-Hf_Cu_mold_S['Dmax'].mean())**2+(Heating_Rate1-Hf_Cu_mold_S['Heating_Rate1'].mean())**2+(Heating_Rate2-Hf_Cu_mold_S['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Hf_Cu_mold_I['Tg'].mean())**2+(Tx-Hf_Cu_mold_I['Tx'].mean())**2+(Tl-Hf_Cu_mold_I['Tl'].mean())**2+(Dmax-Hf_Cu_mold_I['Dmax'].mean())**2+(Heating_Rate1-Hf_Cu_mold_I['Heating_Rate1'].mean())**2+(Heating_Rate2-Hf_Cu_mold_I['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Hf_Cu_mold_W['Tg'].mean())**2+(Tx-Hf_Cu_mold_W['Tx'].mean())**2+(Tl-Hf_Cu_mold_W['Tl'].mean())**2+(Dmax-Hf_Cu_mold_W['Dmax'].mean())**2+(Heating_Rate1-Hf_Cu_mold_W['Heating_Rate1'].mean())**2+(Heating_Rate2-Hf_Cu_mold_W['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Hf_Cu_mold_C['Tg'].mean())**2+(Tx-Hf_Cu_mold_C['Tx'].mean())**2+(Tl-Hf_Cu_mold_C['Tl'].mean())**2+(Dmax-Hf_Cu_mold_C['Dmax'].mean())**2+(Heating_Rate1-Hf_Cu_mold_C['Heating_Rate1'].mean())**2+(Heating_Rate2-Hf_Cu_mold_C['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Hf_Cu_mold_HPDC['Tg'].mean())**2+(Tx-Hf_Cu_mold_HPDC['Tx'].mean())**2+(Tl-Hf_Cu_mold_HPDC['Tl'].mean())**2+(Dmax-Hf_Cu_mold_HPDC['Dmax'].mean())**2+(Heating_Rate1-Hf_Cu_mold_HPDC['Heating_Rate1'].mean())**2+(Heating_Rate2-Hf_Cu_mold_HPDC['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Hf_Melt_spin['Tg'].mean())**2+(Tx-Hf_Melt_spin['Tx'].mean())**2+(Tl-Hf_Melt_spin['Tl'].mean())**2+(Dmax-Hf_Melt_spin['Dmax'].mean())**2+(Heating_Rate1-Hf_Melt_spin['Heating_Rate1'].mean())**2+(Heating_Rate2-Hf_Melt_spin['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Hf_SiO2_tube['Tg'].mean())**2+(Tx-Hf_SiO2_tube['Tx'].mean())**2+(Tl-Hf_SiO2_tube['Tl'].mean())**2+(Dmax-Hf_SiO2_tube['Dmax'].mean())**2+(Heating_Rate1-Hf_SiO2_tube['Heating_Rate1'].mean())**2+(Heating_Rate2-Hf_SiO2_tube['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Hf_Brass_M['Tg'].mean())**2+(Tx-Hf_Brass_M['Tx'].mean())**2+(Tl-Hf_Brass_M['Tl'].mean())**2+(Dmax-Hf_Brass_M['Dmax'].mean())**2+(Heating_Rate1-Hf_Brass_M['Heating_Rate1'].mean())**2+(Heating_Rate2-Hf_Brass_M['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Hf_CLELP['Tg'].mean())**2+(Tx-Hf_CLELP['Tx'].mean())**2+(Tl-Hf_CLELP['Tl'].mean())**2+(Dmax-Hf_CLELP['Dmax'].mean())**2+(Heating_Rate1-Hf_CLELP['Heating_Rate1'].mean())**2+(Heating_Rate2-Hf_CLELP['Heating_Rate2'].mean())**2)**0.5) 
    
    distance.append(((Tg-Hf_Cu_mold_D['Tg'].mean())**2+(Tx-Hf_Cu_mold_D['Tx'].mean())**2+(Tl-Hf_Cu_mold_D['Tl'].mean())**2+(Dmax-Hf_Cu_mold_D['Dmax'].mean())**2+(Heating_Rate1-Hf_Cu_mold_D['Heating_Rate1'].mean())**2+(Heating_Rate2-Hf_Cu_mold_D['Heating_Rate2'].mean())**2)**0.5)
    



    #print(distance)
    distance_1 = [x for x in distance if ~np.isnan(x)]
    key = min(distance_1)
    for i in range(0,11):
        if key == distance[i]:
            a = i
    #print(distance_1)
    if (a == 0):
        a1="Cu mold"
        return(a1)
    elif(a == 1):
        a2="Cu mold S"
        return(a2)
    elif(a == 2):
        a3="Cu mold I"
        return(a3)
    elif(a == 3):
        a4="Cu mold W"
        return(a4)
    elif(a == 4):
        a5="Cu mold C"
        return(a5)
    elif(a == 5):
        a6="Cu mold HPDC"
        return(a6)
    elif(a == 6):
        a7="Melt Spin"
        return(a7)
    elif(a == 7):
        a8="SiO2 Tube"
        return(a8)
    elif(a == 8):
        a9="Brass M"
        return(a9)
    elif(a == 9):
        a10="CLELP"
        return(a10)
    elif(a  == 10):
        a11="Cu mold D"
        return(a11)

# %%
def Gd(Tg,Tx,Tl,Dmax,Heating_Rate1,Heating_Rate2):
    distance=[]
    distance_1 = []
    distance.append(((Tg-Gd_Cu_mold['Tg'].mean())**2+(Tx-Gd_Cu_mold['Tx'].mean())**2+(Tl-Gd_Cu_mold['Tl'].mean())**2+(Dmax-Gd_Cu_mold['Dmax'].mean())**2+(Heating_Rate1-Gd_Cu_mold['Heating_Rate1'].mean())**2+(Heating_Rate2-Gd_Cu_mold['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Gd_Cu_mold_S['Tg'].mean())**2+(Tx-Gd_Cu_mold_S['Tx'].mean())**2+(Tl-Gd_Cu_mold_S['Tl'].mean())**2+(Dmax-Gd_Cu_mold_S['Dmax'].mean())**2+(Heating_Rate1-Gd_Cu_mold_S['Heating_Rate1'].mean())**2+(Heating_Rate2-Gd_Cu_mold_S['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Gd_Cu_mold_I['Tg'].mean())**2+(Tx-Gd_Cu_mold_I['Tx'].mean())**2+(Tl-Gd_Cu_mold_I['Tl'].mean())**2+(Dmax-Gd_Cu_mold_I['Dmax'].mean())**2+(Heating_Rate1-Gd_Cu_mold_I['Heating_Rate1'].mean())**2+(Heating_Rate2-Gd_Cu_mold_I['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Gd_Cu_mold_W['Tg'].mean())**2+(Tx-Gd_Cu_mold_W['Tx'].mean())**2+(Tl-Gd_Cu_mold_W['Tl'].mean())**2+(Dmax-Gd_Cu_mold_W['Dmax'].mean())**2+(Heating_Rate1-Gd_Cu_mold_W['Heating_Rate1'].mean())**2+(Heating_Rate2-Gd_Cu_mold_W['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Gd_Cu_mold_C['Tg'].mean())**2+(Tx-Gd_Cu_mold_C['Tx'].mean())**2+(Tl-Gd_Cu_mold_C['Tl'].mean())**2+(Dmax-Gd_Cu_mold_C['Dmax'].mean())**2+(Heating_Rate1-Gd_Cu_mold_C['Heating_Rate1'].mean())**2+(Heating_Rate2-Gd_Cu_mold_C['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Gd_Cu_mold_HPDC['Tg'].mean())**2+(Tx-Gd_Cu_mold_HPDC['Tx'].mean())**2+(Tl-Gd_Cu_mold_HPDC['Tl'].mean())**2+(Dmax-Gd_Cu_mold_HPDC['Dmax'].mean())**2+(Heating_Rate1-Gd_Cu_mold_HPDC['Heating_Rate1'].mean())**2+(Heating_Rate2-Gd_Cu_mold_HPDC['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Gd_Melt_spin['Tg'].mean())**2+(Tx-Gd_Melt_spin['Tx'].mean())**2+(Tl-Gd_Melt_spin['Tl'].mean())**2+(Dmax-Gd_Melt_spin['Dmax'].mean())**2+(Heating_Rate1-Gd_Melt_spin['Heating_Rate1'].mean())**2+(Heating_Rate2-Gd_Melt_spin['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Gd_SiO2_tube['Tg'].mean())**2+(Tx-Gd_SiO2_tube['Tx'].mean())**2+(Tl-Gd_SiO2_tube['Tl'].mean())**2+(Dmax-Gd_SiO2_tube['Dmax'].mean())**2+(Heating_Rate1-Gd_SiO2_tube['Heating_Rate1'].mean())**2+(Heating_Rate2-Gd_SiO2_tube['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Gd_Brass_M['Tg'].mean())**2+(Tx-Gd_Brass_M['Tx'].mean())**2+(Tl-Gd_Brass_M['Tl'].mean())**2+(Dmax-Gd_Brass_M['Dmax'].mean())**2+(Heating_Rate1-Gd_Brass_M['Heating_Rate1'].mean())**2+(Heating_Rate2-Gd_Brass_M['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Gd_CLELP['Tg'].mean())**2+(Tx-Gd_CLELP['Tx'].mean())**2+(Tl-Gd_CLELP['Tl'].mean())**2+(Dmax-Gd_CLELP['Dmax'].mean())**2+(Heating_Rate1-Gd_CLELP['Heating_Rate1'].mean())**2+(Heating_Rate2-Gd_CLELP['Heating_Rate2'].mean())**2)**0.5) 
    
    distance.append(((Tg-Gd_Cu_mold_D['Tg'].mean())**2+(Tx-Gd_Cu_mold_D['Tx'].mean())**2+(Tl-Gd_Cu_mold_D['Tl'].mean())**2+(Dmax-Gd_Cu_mold_D['Dmax'].mean())**2+(Heating_Rate1-Gd_Cu_mold_D['Heating_Rate1'].mean())**2+(Heating_Rate2-Gd_Cu_mold_D['Heating_Rate2'].mean())**2)**0.5)
    


    #print(distance)
    distance_1 = [x for x in distance if ~np.isnan(x)]
    key = min(distance_1)
    for i in range(0,11):
        if key == distance[i]:
            a = i
   # print(distance_1)
    if (a == 0):
        a1="Cu mold"
        return(a1)
    elif(a == 1):
        a2="Cu mold S"
        return(a2)
    elif(a == 2):
        a3="Cu mold I"
        return(a3)
    elif(a == 3):
        a4="Cu mold W"
        return(a4)
    elif(a == 4):
        a5="Cu mold C"
        return(a5)
    elif(a == 5):
        a6="Cu mold HPDC"
        return(a6)
    elif(a == 6):
        a7="Melt Spin"
        return(a7)
    elif(a == 7):
        a8="SiO2 Tube"
        return(a8)
    elif(a == 8):
        a9="Brass M"
        return(a9)
    elif(a == 9):
        a10="CLELP"
        return(a10)
    elif(a  == 10):
        a11="Cu mold D"
        return(a11)

# %%
def Zr(Tg,Tx,Tl,Dmax,Heating_Rate1,Heating_Rate2):
    distance=[]
    distance_1 = []
    distance.append(((Tg-Zr_Cu_mold['Tg'].mean())**2+(Tx-Zr_Cu_mold['Tx'].mean())**2+(Tl-Zr_Cu_mold['Tl'].mean())**2+(Dmax-Zr_Cu_mold['Dmax'].mean())**2+(Heating_Rate1-Zr_Cu_mold['Heating_Rate1'].mean())**2+(Heating_Rate2-Zr_Cu_mold['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Zr_Cu_mold_S['Tg'].mean())**2+(Tx-Zr_Cu_mold_S['Tx'].mean())**2+(Tl-Zr_Cu_mold_S['Tl'].mean())**2+(Dmax-Zr_Cu_mold_S['Dmax'].mean())**2+(Heating_Rate1-Zr_Cu_mold_S['Heating_Rate1'].mean())**2+(Heating_Rate2-Zr_Cu_mold_S['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Zr_Cu_mold_I['Tg'].mean())**2+(Tx-Zr_Cu_mold_I['Tx'].mean())**2+(Tl-Zr_Cu_mold_I['Tl'].mean())**2+(Dmax-Zr_Cu_mold_I['Dmax'].mean())**2+(Heating_Rate1-Zr_Cu_mold_I['Heating_Rate1'].mean())**2+(Heating_Rate2-Zr_Cu_mold_I['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Zr_Cu_mold_W['Tg'].mean())**2+(Tx-Zr_Cu_mold_W['Tx'].mean())**2+(Tl-Zr_Cu_mold_W['Tl'].mean())**2+(Dmax-Zr_Cu_mold_W['Dmax'].mean())**2+(Heating_Rate1-Zr_Cu_mold_W['Heating_Rate1'].mean())**2+(Heating_Rate2-Zr_Cu_mold_W['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Zr_Cu_mold_C['Tg'].mean())**2+(Tx-Zr_Cu_mold_C['Tx'].mean())**2+(Tl-Zr_Cu_mold_C['Tl'].mean())**2+(Dmax-Zr_Cu_mold_C['Dmax'].mean())**2+(Heating_Rate1-Zr_Cu_mold_C['Heating_Rate1'].mean())**2+(Heating_Rate2-Zr_Cu_mold_C['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Zr_Cu_mold_HPDC['Tg'].mean())**2+(Tx-Zr_Cu_mold_HPDC['Tx'].mean())**2+(Tl-Zr_Cu_mold_HPDC['Tl'].mean())**2+(Dmax-Zr_Cu_mold_HPDC['Dmax'].mean())**2+(Heating_Rate1-Zr_Cu_mold_HPDC['Heating_Rate1'].mean())**2+(Heating_Rate2-Zr_Cu_mold_HPDC['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Zr_Melt_spin['Tg'].mean())**2+(Tx-Zr_Melt_spin['Tx'].mean())**2+(Tl-Zr_Melt_spin['Tl'].mean())**2+(Dmax-Zr_Melt_spin['Dmax'].mean())**2+(Heating_Rate1-Zr_Melt_spin['Heating_Rate1'].mean())**2+(Heating_Rate2-Zr_Melt_spin['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Zr_SiO2_tube['Tg'].mean())**2+(Tx-Zr_SiO2_tube['Tx'].mean())**2+(Tl-Zr_SiO2_tube['Tl'].mean())**2+(Dmax-Zr_SiO2_tube['Dmax'].mean())**2+(Heating_Rate1-Zr_SiO2_tube['Heating_Rate1'].mean())**2+(Heating_Rate2-Zr_SiO2_tube['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Zr_Brass_M['Tg'].mean())**2+(Tx-Zr_Brass_M['Tx'].mean())**2+(Tl-Zr_Brass_M['Tl'].mean())**2+(Dmax-Zr_Brass_M['Dmax'].mean())**2+(Heating_Rate1-Zr_Brass_M['Heating_Rate1'].mean())**2+(Heating_Rate2-Zr_Brass_M['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Zr_CLELP['Tg'].mean())**2+(Tx-Zr_CLELP['Tx'].mean())**2+(Tl-Zr_CLELP['Tl'].mean())**2+(Dmax-Zr_CLELP['Dmax'].mean())**2+(Heating_Rate1-Zr_CLELP['Heating_Rate1'].mean())**2+(Heating_Rate2-Zr_CLELP['Heating_Rate2'].mean())**2)**0.5) 
    
    distance.append(((Tg-Zr_Cu_mold_D['Tg'].mean())**2+(Tx-Zr_Cu_mold_D['Tx'].mean())**2+(Tl-Zr_Cu_mold_D['Tl'].mean())**2+(Dmax-Zr_Cu_mold_D['Dmax'].mean())**2+(Heating_Rate1-Zr_Cu_mold_D['Heating_Rate1'].mean())**2+(Heating_Rate2-Zr_Cu_mold_D['Heating_Rate2'].mean())**2)**0.5)
    



    #print(distance)
    distance_1 = [x for x in distance if ~np.isnan(x)]
    key = min(distance_1)
    for i in range(0,11):
        if key == distance[i]:
            a = i
    #print(distance_1)
    if (a == 0):
        a1="Cu mold"
        return(a1)
    elif(a == 1):
        a2="Cu mold S"
        return(a2)
    elif(a == 2):
        a3="Cu mold I"
        return(a3)
    elif(a == 3):
        a4="Cu mold W"
        return(a4)
    elif(a == 4):
        a5="Cu mold C"
        return(a5)
    elif(a == 5):
        a6="Cu mold HPDC"
        return(a6)
    elif(a == 6):
        a7="Melt Spin"
        return(a7)
    elif(a == 7):
        a8="SiO2 Tube"
        return(a8)
    elif(a == 8):
        a9="Brass M"
        return(a9)
    elif(a == 9):
        a10="CLELP"
        return(a10)
    elif(a  == 10):
        a11="Cu mold D"
        return(a11)

# %%
def Ni(Tg,Tx,Tl,Dmax,Heating_Rate1,Heating_Rate2):
    distance=[]
    distance_1 = []
    distance.append(((Tg-Ni_Cu_mold['Tg'].mean())**2+(Tx-Ni_Cu_mold['Tx'].mean())**2+(Tl-Ni_Cu_mold['Tl'].mean())**2+(Dmax-Ni_Cu_mold['Dmax'].mean())**2+(Heating_Rate1-Ni_Cu_mold['Heating_Rate1'].mean())**2+(Heating_Rate2-Ni_Cu_mold['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ni_Cu_mold_S['Tg'].mean())**2+(Tx-Ni_Cu_mold_S['Tx'].mean())**2+(Tl-Ni_Cu_mold_S['Tl'].mean())**2+(Dmax-Ni_Cu_mold_S['Dmax'].mean())**2+(Heating_Rate1-Ni_Cu_mold_S['Heating_Rate1'].mean())**2+(Heating_Rate2-Ni_Cu_mold_S['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ni_Cu_mold_I['Tg'].mean())**2+(Tx-Ni_Cu_mold_I['Tx'].mean())**2+(Tl-Ni_Cu_mold_I['Tl'].mean())**2+(Dmax-Ni_Cu_mold_I['Dmax'].mean())**2+(Heating_Rate1-Ni_Cu_mold_I['Heating_Rate1'].mean())**2+(Heating_Rate2-Ni_Cu_mold_I['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ni_Cu_mold_W['Tg'].mean())**2+(Tx-Ni_Cu_mold_W['Tx'].mean())**2+(Tl-Ni_Cu_mold_W['Tl'].mean())**2+(Dmax-Ni_Cu_mold_W['Dmax'].mean())**2+(Heating_Rate1-Ni_Cu_mold_W['Heating_Rate1'].mean())**2+(Heating_Rate2-Ni_Cu_mold_W['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ni_Cu_mold_C['Tg'].mean())**2+(Tx-Ni_Cu_mold_C['Tx'].mean())**2+(Tl-Ni_Cu_mold_C['Tl'].mean())**2+(Dmax-Ni_Cu_mold_C['Dmax'].mean())**2+(Heating_Rate1-Ni_Cu_mold_C['Heating_Rate1'].mean())**2+(Heating_Rate2-Ni_Cu_mold_C['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ni_Cu_mold_HPDC['Tg'].mean())**2+(Tx-Ni_Cu_mold_HPDC['Tx'].mean())**2+(Tl-Ni_Cu_mold_HPDC['Tl'].mean())**2+(Dmax-Ni_Cu_mold_HPDC['Dmax'].mean())**2+(Heating_Rate1-Ni_Cu_mold_HPDC['Heating_Rate1'].mean())**2+(Heating_Rate2-Ni_Cu_mold_HPDC['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ni_Melt_spin['Tg'].mean())**2+(Tx-Ni_Melt_spin['Tx'].mean())**2+(Tl-Ni_Melt_spin['Tl'].mean())**2+(Dmax-Ni_Melt_spin['Dmax'].mean())**2+(Heating_Rate1-Ni_Melt_spin['Heating_Rate1'].mean())**2+(Heating_Rate2-Ni_Melt_spin['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ni_SiO2_tube['Tg'].mean())**2+(Tx-Ni_SiO2_tube['Tx'].mean())**2+(Tl-Ni_SiO2_tube['Tl'].mean())**2+(Dmax-Ni_SiO2_tube['Dmax'].mean())**2+(Heating_Rate1-Ni_SiO2_tube['Heating_Rate1'].mean())**2+(Heating_Rate2-Ni_SiO2_tube['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ni_Brass_M['Tg'].mean())**2+(Tx-Ni_Brass_M['Tx'].mean())**2+(Tl-Ni_Brass_M['Tl'].mean())**2+(Dmax-Ni_Brass_M['Dmax'].mean())**2+(Heating_Rate1-Ni_Brass_M['Heating_Rate1'].mean())**2+(Heating_Rate2-Ni_Brass_M['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Ni_CLELP['Tg'].mean())**2+(Tx-Ni_CLELP['Tx'].mean())**2+(Tl-Ni_CLELP['Tl'].mean())**2+(Dmax-Ni_CLELP['Dmax'].mean())**2+(Heating_Rate1-Ni_CLELP['Heating_Rate1'].mean())**2+(Heating_Rate2-Ni_CLELP['Heating_Rate2'].mean())**2)**0.5) 
    
    distance.append(((Tg-Ni_Cu_mold_D['Tg'].mean())**2+(Tx-Ni_Cu_mold_D['Tx'].mean())**2+(Tl-Ni_Cu_mold_D['Tl'].mean())**2+(Dmax-Ni_Cu_mold_D['Dmax'].mean())**2+(Heating_Rate1-Ni_Cu_mold_D['Heating_Rate1'].mean())**2+(Heating_Rate2-Ni_Cu_mold_D['Heating_Rate2'].mean())**2)**0.5)
    



    #print(distance)
    distance_1 = [x for x in distance if ~np.isnan(x)]
    
    key = min(distance_1)
    for i in range(0,11):
        if key == distance[i]:
            a = i
    #print(distance_1)
    
    if (a == 0):
        a1="Cu mold"
        return(a1)
    elif(a == 1):
        a2="Cu mold S"
        return(a2)
    elif(a == 2):
        a3="Cu mold I"
        return(a3)
    elif(a == 3):
        a4="Cu mold W"
        return(a4)
    elif(a == 4):
        a5="Cu mold C"
        return(a5)
    elif(a == 5):
        a6="Cu mold HPDC"
        return(a6)
    elif(a == 6):
        a7="Melt Spin"
        return(a7)
    elif(a == 7):
        a8="SiO2 Tube"
        return(a8)
    elif(a == 8):
        a9="Brass M"
        return(a9)
    elif(a == 9):
        a10="CLELP"
        return(a10)
    elif(a  == 10):
        a11="Cu mold D"
        return(a11)

# %%
def Pr(Tg,Tx,Tl,Dmax,Heating_Rate1,Heating_Rate2):
    distance=[]
    distance_1 = []
    distance.append(((Tg-Pr_Cu_mold['Tg'].mean())**2+(Tx-Pr_Cu_mold['Tx'].mean())**2+(Tl-Pr_Cu_mold['Tl'].mean())**2+(Dmax-Pr_Cu_mold['Dmax'].mean())**2+(Heating_Rate1-Pr_Cu_mold['Heating_Rate1'].mean())**2+(Heating_Rate2-Pr_Cu_mold['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Pr_Cu_mold_S['Tg'].mean())**2+(Tx-Pr_Cu_mold_S['Tx'].mean())**2+(Tl-Pr_Cu_mold_S['Tl'].mean())**2+(Dmax-Pr_Cu_mold_S['Dmax'].mean())**2+(Heating_Rate1-Pr_Cu_mold_S['Heating_Rate1'].mean())**2+(Heating_Rate2-Pr_Cu_mold_S['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Pr_Cu_mold_I['Tg'].mean())**2+(Tx-Pr_Cu_mold_I['Tx'].mean())**2+(Tl-Pr_Cu_mold_I['Tl'].mean())**2+(Dmax-Pr_Cu_mold_I['Dmax'].mean())**2+(Heating_Rate1-Pr_Cu_mold_I['Heating_Rate1'].mean())**2+(Heating_Rate2-Pr_Cu_mold_I['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Pr_Cu_mold_W['Tg'].mean())**2+(Tx-Pr_Cu_mold_W['Tx'].mean())**2+(Tl-Pr_Cu_mold_W['Tl'].mean())**2+(Dmax-Pr_Cu_mold_W['Dmax'].mean())**2+(Heating_Rate1-Pr_Cu_mold_W['Heating_Rate1'].mean())**2+(Heating_Rate2-Pr_Cu_mold_W['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Pr_Cu_mold_C['Tg'].mean())**2+(Tx-Pr_Cu_mold_C['Tx'].mean())**2+(Tl-Pr_Cu_mold_C['Tl'].mean())**2+(Dmax-Pr_Cu_mold_C['Dmax'].mean())**2+(Heating_Rate1-Pr_Cu_mold_C['Heating_Rate1'].mean())**2+(Heating_Rate2-Pr_Cu_mold_C['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Pr_Cu_mold_HPDC['Tg'].mean())**2+(Tx-Pr_Cu_mold_HPDC['Tx'].mean())**2+(Tl-Pr_Cu_mold_HPDC['Tl'].mean())**2+(Dmax-Pr_Cu_mold_HPDC['Dmax'].mean())**2+(Heating_Rate1-Pr_Cu_mold_HPDC['Heating_Rate1'].mean())**2+(Heating_Rate2-Pr_Cu_mold_HPDC['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Pr_Melt_spin['Tg'].mean())**2+(Tx-Pr_Melt_spin['Tx'].mean())**2+(Tl-Pr_Melt_spin['Tl'].mean())**2+(Dmax-Pr_Melt_spin['Dmax'].mean())**2+(Heating_Rate1-Pr_Melt_spin['Heating_Rate1'].mean())**2+(Heating_Rate2-Pr_Melt_spin['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Pr_SiO2_tube['Tg'].mean())**2+(Tx-Pr_SiO2_tube['Tx'].mean())**2+(Tl-Pr_SiO2_tube['Tl'].mean())**2+(Dmax-Pr_SiO2_tube['Dmax'].mean())**2+(Heating_Rate1-Pr_SiO2_tube['Heating_Rate1'].mean())**2+(Heating_Rate2-Pr_SiO2_tube['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Pr_Brass_M['Tg'].mean())**2+(Tx-Pr_Brass_M['Tx'].mean())**2+(Tl-Pr_Brass_M['Tl'].mean())**2+(Dmax-Pr_Brass_M['Dmax'].mean())**2+(Heating_Rate1-Pr_Brass_M['Heating_Rate1'].mean())**2+(Heating_Rate2-Pr_Brass_M['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Pr_CLELP['Tg'].mean())**2+(Tx-Pr_CLELP['Tx'].mean())**2+(Tl-Pr_CLELP['Tl'].mean())**2+(Dmax-Pr_CLELP['Dmax'].mean())**2+(Heating_Rate1-Pr_CLELP['Heating_Rate1'].mean())**2+(Heating_Rate2-Pr_CLELP['Heating_Rate2'].mean())**2)**0.5) 
    
    distance.append(((Tg-Pr_Cu_mold_D['Tg'].mean())**2+(Tx-Pr_Cu_mold_D['Tx'].mean())**2+(Tl-Pr_Cu_mold_D['Tl'].mean())**2+(Dmax-Pr_Cu_mold_D['Dmax'].mean())**2+(Heating_Rate1-Pr_Cu_mold_D['Heating_Rate1'].mean())**2+(Heating_Rate2-Pr_Cu_mold_D['Heating_Rate2'].mean())**2)**0.5)
    



    #print(distance)
    distance_1 = [x for x in distance if ~np.isnan(x)]
    
    key = min(distance_1)
    for i in range(0,11):
        if key == distance[i]:
            a = i
    #print(distance_1)
    
    if (a == 0):
        a1="Cu mold"
        return(a1)
    elif(a == 1):
        a2="Cu mold S"
        return(a2)
    elif(a == 2):
        a3="Cu mold I"
        return(a3)
    elif(a == 3):
        a4="Cu mold W"
        return(a4)
    elif(a == 4):
        a5="Cu mold C"
        return(a5)
    elif(a == 5):
        a6="Cu mold HPDC"
        return(a6)
    elif(a == 6):
        a7="Melt Spin"
        return(a7)
    elif(a == 7):
        a8="SiO2 Tube"
        return(a8)
    elif(a == 8):
        a9="Brass M"
        return(a9)
    elif(a == 9):
        a10="CLELP"
        return(a10)
    elif(a  == 10):
        a11="Cu mold D"
        return(a11)

# %%
def Y(Tg,Tx,Tl,Dmax,Heating_Rate1,Heating_Rate2):
    distance=[]
    distance_1 = []
    distance.append(((Tg-Y_Cu_mold['Tg'].mean())**2+(Tx-Y_Cu_mold['Tx'].mean())**2+(Tl-Y_Cu_mold['Tl'].mean())**2+(Dmax-Y_Cu_mold['Dmax'].mean())**2+(Heating_Rate1-Y_Cu_mold['Heating_Rate1'].mean())**2+(Heating_Rate2-Y_Cu_mold['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Y_Cu_mold_S['Tg'].mean())**2+(Tx-Y_Cu_mold_S['Tx'].mean())**2+(Tl-Y_Cu_mold_S['Tl'].mean())**2+(Dmax-Y_Cu_mold_S['Dmax'].mean())**2+(Heating_Rate1-Y_Cu_mold_S['Heating_Rate1'].mean())**2+(Heating_Rate2-Y_Cu_mold_S['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Y_Cu_mold_I['Tg'].mean())**2+(Tx-Y_Cu_mold_I['Tx'].mean())**2+(Tl-Y_Cu_mold_I['Tl'].mean())**2+(Dmax-Y_Cu_mold_I['Dmax'].mean())**2+(Heating_Rate1-Y_Cu_mold_I['Heating_Rate1'].mean())**2+(Heating_Rate2-Y_Cu_mold_I['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Y_Cu_mold_W['Tg'].mean())**2+(Tx-Y_Cu_mold_W['Tx'].mean())**2+(Tl-Y_Cu_mold_W['Tl'].mean())**2+(Dmax-Y_Cu_mold_W['Dmax'].mean())**2+(Heating_Rate1-Y_Cu_mold_W['Heating_Rate1'].mean())**2+(Heating_Rate2-Y_Cu_mold_W['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Y_Cu_mold_C['Tg'].mean())**2+(Tx-Y_Cu_mold_C['Tx'].mean())**2+(Tl-Y_Cu_mold_C['Tl'].mean())**2+(Dmax-Y_Cu_mold_C['Dmax'].mean())**2+(Heating_Rate1-Y_Cu_mold_C['Heating_Rate1'].mean())**2+(Heating_Rate2-Y_Cu_mold_C['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Y_Cu_mold_HPDC['Tg'].mean())**2+(Tx-Y_Cu_mold_HPDC['Tx'].mean())**2+(Tl-Y_Cu_mold_HPDC['Tl'].mean())**2+(Dmax-Y_Cu_mold_HPDC['Dmax'].mean())**2+(Heating_Rate1-Y_Cu_mold_HPDC['Heating_Rate1'].mean())**2+(Heating_Rate2-Y_Cu_mold_HPDC['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Y_Melt_spin['Tg'].mean())**2+(Tx-Y_Melt_spin['Tx'].mean())**2+(Tl-Y_Melt_spin['Tl'].mean())**2+(Dmax-Y_Melt_spin['Dmax'].mean())**2+(Heating_Rate1-Y_Melt_spin['Heating_Rate1'].mean())**2+(Heating_Rate2-Y_Melt_spin['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Y_SiO2_tube['Tg'].mean())**2+(Tx-Y_SiO2_tube['Tx'].mean())**2+(Tl-Y_SiO2_tube['Tl'].mean())**2+(Dmax-Y_SiO2_tube['Dmax'].mean())**2+(Heating_Rate1-Y_SiO2_tube['Heating_Rate1'].mean())**2+(Heating_Rate2-Y_SiO2_tube['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Y_Brass_M['Tg'].mean())**2+(Tx-Y_Brass_M['Tx'].mean())**2+(Tl-Y_Brass_M['Tl'].mean())**2+(Dmax-Y_Brass_M['Dmax'].mean())**2+(Heating_Rate1-Y_Brass_M['Heating_Rate1'].mean())**2+(Heating_Rate2-Y_Brass_M['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Y_CLELP['Tg'].mean())**2+(Tx-Y_CLELP['Tx'].mean())**2+(Tl-Y_CLELP['Tl'].mean())**2+(Dmax-Y_CLELP['Dmax'].mean())**2+(Heating_Rate1-Y_CLELP['Heating_Rate1'].mean())**2+(Heating_Rate2-Y_CLELP['Heating_Rate2'].mean())**2)**0.5) 
    
    distance.append(((Tg-Y_Cu_mold_D['Tg'].mean())**2+(Tx-Y_Cu_mold_D['Tx'].mean())**2+(Tl-Y_Cu_mold_D['Tl'].mean())**2+(Dmax-Y_Cu_mold_D['Dmax'].mean())**2+(Heating_Rate1-Y_Cu_mold_D['Heating_Rate1'].mean())**2+(Heating_Rate2-Y_Cu_mold_D['Heating_Rate2'].mean())**2)**0.5)
    

    
    
    #print(distance)
    distance_1 = [x for x in distance if ~np.isnan(x)]
    
    key = min(distance_1)
    for i in range(0,11):
        if key == distance[i]:
            a = i
    #print(distance_1)
    
    if (a == 0):
        a1="Cu mold"
        return(a1)
    elif(a == 1):
        a2="Cu mold S"
        return(a2)
    elif(a == 2):
        a3="Cu mold I"
        return(a3)
    elif(a == 3):
        a4="Cu mold W"
        return(a4)
    elif(a == 4):
        a5="Cu mold C"
        return(a5)
    elif(a == 5):
        a6="Cu mold HPDC"
        return(a6)
    elif(a == 6):
        a7="Melt Spin"
        return(a7)
    elif(a == 7):
        a8="SiO2 Tube"
        return(a8)
    elif(a == 8):
        a9="Brass M"
        return(a9)
    elif(a == 9):
        a10="CLELP"
        return(a10)
    elif(a  == 10):
        a11="Cu mold D"
        return(a11)

# %%
def Fe(Tg,Tx,Tl,Dmax,Heating_Rate1,Heating_Rate2):
    distance=[]
    distance_1 = []
    distance.append(((Tg-Fe_Cu_mold['Tg'].mean())**2+(Tx-Fe_Cu_mold['Tx'].mean())**2+(Tl-Fe_Cu_mold['Tl'].mean())**2+(Dmax-Fe_Cu_mold['Dmax'].mean())**2+(Heating_Rate1-Fe_Cu_mold['Heating_Rate1'].mean())**2+(Heating_Rate2-Fe_Cu_mold['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Fe_Cu_mold_S['Tg'].mean())**2+(Tx-Fe_Cu_mold_S['Tx'].mean())**2+(Tl-Fe_Cu_mold_S['Tl'].mean())**2+(Dmax-Fe_Cu_mold_S['Dmax'].mean())**2+(Heating_Rate1-Fe_Cu_mold_S['Heating_Rate1'].mean())**2+(Heating_Rate2-Fe_Cu_mold_S['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Fe_Cu_mold_I['Tg'].mean())**2+(Tx-Fe_Cu_mold_I['Tx'].mean())**2+(Tl-Fe_Cu_mold_I['Tl'].mean())**2+(Dmax-Fe_Cu_mold_I['Dmax'].mean())**2+(Heating_Rate1-Fe_Cu_mold_I['Heating_Rate1'].mean())**2+(Heating_Rate2-Fe_Cu_mold_I['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Fe_Cu_mold_W['Tg'].mean())**2+(Tx-Fe_Cu_mold_W['Tx'].mean())**2+(Tl-Fe_Cu_mold_W['Tl'].mean())**2+(Dmax-Fe_Cu_mold_W['Dmax'].mean())**2+(Heating_Rate1-Fe_Cu_mold_W['Heating_Rate1'].mean())**2+(Heating_Rate2-Fe_Cu_mold_W['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Fe_Cu_mold_C['Tg'].mean())**2+(Tx-Fe_Cu_mold_C['Tx'].mean())**2+(Tl-Fe_Cu_mold_C['Tl'].mean())**2+(Dmax-Fe_Cu_mold_C['Dmax'].mean())**2+(Heating_Rate1-Fe_Cu_mold_C['Heating_Rate1'].mean())**2+(Heating_Rate2-Fe_Cu_mold_C['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Fe_Cu_mold_HPDC['Tg'].mean())**2+(Tx-Fe_Cu_mold_HPDC['Tx'].mean())**2+(Tl-Fe_Cu_mold_HPDC['Tl'].mean())**2+(Dmax-Fe_Cu_mold_HPDC['Dmax'].mean())**2+(Heating_Rate1-Fe_Cu_mold_HPDC['Heating_Rate1'].mean())**2+(Heating_Rate2-Fe_Cu_mold_HPDC['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Fe_Melt_spin['Tg'].mean())**2+(Tx-Fe_Melt_spin['Tx'].mean())**2+(Tl-Fe_Melt_spin['Tl'].mean())**2+(Dmax-Fe_Melt_spin['Dmax'].mean())**2+(Heating_Rate1-Fe_Melt_spin['Heating_Rate1'].mean())**2+(Heating_Rate2-Fe_Melt_spin['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Fe_SiO2_tube['Tg'].mean())**2+(Tx-Fe_SiO2_tube['Tx'].mean())**2+(Tl-Fe_SiO2_tube['Tl'].mean())**2+(Dmax-Fe_SiO2_tube['Dmax'].mean())**2+(Heating_Rate1-Fe_SiO2_tube['Heating_Rate1'].mean())**2+(Heating_Rate2-Fe_SiO2_tube['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Fe_Brass_M['Tg'].mean())**2+(Tx-Fe_Brass_M['Tx'].mean())**2+(Tl-Fe_Brass_M['Tl'].mean())**2+(Dmax-Fe_Brass_M['Dmax'].mean())**2+(Heating_Rate1-Fe_Brass_M['Heating_Rate1'].mean())**2+(Heating_Rate2-Fe_Brass_M['Heating_Rate2'].mean())**2)**0.5)
    
    distance.append(((Tg-Fe_CLELP['Tg'].mean())**2+(Tx-Fe_CLELP['Tx'].mean())**2+(Tl-Fe_CLELP['Tl'].mean())**2+(Dmax-Fe_CLELP['Dmax'].mean())**2+(Heating_Rate1-Fe_CLELP['Heating_Rate1'].mean())**2+(Heating_Rate2-Fe_CLELP['Heating_Rate2'].mean())**2)**0.5) 
    
    distance.append(((Tg-Fe_Cu_mold_D['Tg'].mean())**2+(Tx-Fe_Cu_mold_D['Tx'].mean())**2+(Tl-Fe_Cu_mold_D['Tl'].mean())**2+(Dmax-Fe_Cu_mold_D['Dmax'].mean())**2+(Heating_Rate1-Fe_Cu_mold_D['Heating_Rate1'].mean())**2+(Heating_Rate2-Fe_Cu_mold_D['Heating_Rate2'].mean())**2)**0.5)
    

    
    
    #print(distance)
    distance_1 = [x for x in distance if ~np.isnan(x)]
    
    key = min(distance_1)
    for i in range(0,11):
        if key == distance[i]:
            a = i
    #print(distance_1)
    
    if (a == 0):
        a1="Cu mold"
        return(a1)
    elif(a == 1):
        a2="Cu mold S"
        return(a2)
    elif(a == 2):
        a3="Cu mold I"
        return(a3)
    elif(a == 3):
        a4="Cu mold W"
        return(a4)
    elif(a == 4):
        a5="Cu mold C"
        return(a5)
    elif(a == 5):
        a6="Cu mold HPDC"
        return(a6)
    elif(a == 6):
        a7="Melt Spin"
        return(a7)
    elif(a == 7):
        a8="SiO2 Tube"
        return(a8)
    elif(a == 8):
        a9="Brass M"
        return(a9)
    elif(a == 9):
        a10="CLELP"
        return(a10)
    elif(a  == 10):
        a11="Cu mold D"
        return(a11)

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
# Out:
# <ipython-input-796-1390d13c0cdd>:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
test
# Out:
#                                        Alloy     Tg     Tx      Tl  Dmax  \
# 307  Fe63C15Mo14Er2B6                         771.0  830.0  1389.0  3.0
# 577  Zr44Au4Cu36Al8Ag8                        713.0  806.0  1153.0  20.0
# 305  Fe61B15Mo7Zr8Co5Y2Cr2                    901.1  958.9  1490.0  5.0
# 561  (Ti0.45Cu0.378Zr0.10Ni0.072)100?6Sn6     683.0  739.0  1169.0  1.0
# 285  Zr48Cu36Ag8Al8                           690.0  791.0  1143.0  25.0
# 107  Ca47.5Mg22.5Cu30                         399.0  440.0  673.0   6.0
# 160  Mg57Cu31.5Y9.2Nd2.3                      428.0  502.0  777.0   10.0
# 0    Hf47Cu29.25Ni9.75Al14                    790.0  875.0  1278.0  10.0
# 473  Cu50Mg18.2Ca31.8                         392.0  421.0  828.0   2.0
# 370  Ni42Ti20Zr25Al8Cu5                       748.0  803.0  1366.0  0.5
# 318  Fe42.768Co28.512B19.008Si4.752Nb3.96Cr1  827.0  871.0  1462.0  4.0
# 358  Fe75Mo4P10C4B4Si3                        752.0  799.0  1227.0  4.0
# ...

# %%
count=0
total_comp=len(test)

for index,row in test.iterrows( ):
    if(row['Alloy'].startswith('Cu')|row['Alloy'].startswith('(Cu') ):
        print(row['Alloy'])
        fav=Cu(row['Tg'],row['Tx'],row['Tl'],row['Dmax'],row['Heating_Rate1'],row['Heating_Rate2'])
        if(fav == row['Fabrication_Method']):
            count=count+1
        print(fav)
        print(row['Fabrication_Method'])
    elif(row['Alloy'].startswith('Ca')):
        print(row['Alloy'])
        fav=Ca(row['Tg'],row['Tx'],row['Tl'],row['Dmax'],row['Heating_Rate1'],row['Heating_Rate2'])
        if(fav ==row['Fabrication_Method']):
            count=count+1
        print(fav)
        print(row['Fabrication_Method'])
    elif(row['Alloy'].startswith('Mg')):
        print(row['Alloy'])
        fav=Mg(row['Tg'],row['Tx'],row['Tl'],row['Dmax'],row['Heating_Rate1'],row['Heating_Rate2'])
        if(fav ==row['Fabrication_Method']):
            count=count+1
        print(fav)
        print(row['Fabrication_Method'])
    elif(row['Alloy'].startswith('La')):
        print(row['Alloy'])
        fav=La(row['Tg'],row['Tx'],row['Tl'],row['Dmax'],row['Heating_Rate1'],row['Heating_Rate2'])
        if(fav ==row['Fabrication_Method']):
            count=count+1
        print(fav)
        print(row['Fabrication_Method'])
    elif(row['Alloy'].startswith('Pd')):
        print(row['Alloy'])
        fav=Pd(row['Tg'],row['Tx'],row['Tl'],row['Dmax'],row['Heating_Rate1'],row['Heating_Rate2'])
        if(fav ==row['Fabrication_Method']):
            count=count+1
        print(fav)
        print(row['Fabrication_Method'])  
    elif(row['Alloy'].startswith('Ti')|row['Alloy'].startswith('(Ti')):
        print(row['Alloy'])
        fav=Ti(row['Tg'],row['Tx'],row['Tl'],row['Dmax'],row['Heating_Rate1'],row['Heating_Rate2'])
        if(fav ==row['Fabrication_Method']):
            count=count+1
        print(fav)
        print(row['Fabrication_Method'])   
    elif(row['Alloy'].startswith('Co')):
        print(row['Alloy'])
        fav=Co(row['Tg'],row['Tx'],row['Tl'],row['Dmax'],row['Heating_Rate1'],row['Heating_Rate2'])
        if(fav ==row['Fabrication_Method']):
            count=count+1
        print(fav)
        print(row['Fabrication_Method'])    
    elif(row['Alloy'].startswith('Au')):
        print(row['Alloy'])
        fav=Au(row['Tg'],row['Tx'],row['Tl'],row['Dmax'],row['Heating_Rate1'],row['Heating_Rate2'])
        if(fav ==row['Fabrication_Method']):
            count=count+1
        print(fav)
        print(row['Fabrication_Method'])    
    elif(row['Alloy'].startswith('Ag')):
        print(row['Alloy'])
        fav=Ag(row['Tg'],row['Tx'],row['Tl'],row['Dmax'],row['Heating_Rate1'],row['Heating_Rate2'])
        if(fav ==row['Fabrication_Method']):
            count=count+1
        print(fav)
        print(row['Fabrication_Method'])  
    elif(row['Alloy'].startswith('Hf')):
        print(row['Alloy'])
        fav=Hf(row['Tg'],row['Tx'],row['Tl'],row['Dmax'],row['Heating_Rate1'],row['Heating_Rate2'])
        if(fav ==row['Fabrication_Method']):
            count=count+1
        print(fav)
        print(row['Fabrication_Method']) 
    elif(row['Alloy'].startswith('Gd')):
        print(row['Alloy'])
        fav=Gd(row['Tg'],row['Tx'],row['Tl'],row['Dmax'],row['Heating_Rate1'],row['Heating_Rate2'])
        if(fav ==row['Fabrication_Method']):
            count=count+1
        print(fav)
        print(row['Fabrication_Method'])   
    elif(row['Alloy'].startswith('Zr') |row['Alloy'].startswith('(Zr')):
        print(row['Alloy'])
        fav=Zr(row['Tg'],row['Tx'],row['Tl'],row['Dmax'],row['Heating_Rate1'],row['Heating_Rate2'])
        if(fav ==row['Fabrication_Method']):
            count=count+1
        print(fav)
        print(row['Fabrication_Method'])    
    elif(row['Alloy'].startswith('Ni')):
        print(row['Alloy'])
        if(fav ==row['Fabrication_Method']):
            count=count+1
        print(fav)
        fav=Ni(row['Tg'],row['Tx'],row['Tl'],row['Dmax'],row['Heating_Rate1'],row['Heating_Rate2'])
        print(row['Fabrication_Method']) 
    elif(row['Alloy'].startswith('Pr')):
        print(row['Alloy'])
        fav=Pr(row['Tg'],row['Tx'],row['Tl'],row['Dmax'],row['Heating_Rate1'],row['Heating_Rate2'])
        if(fav ==row['Fabrication_Method']):
            count=count+1
        print(fav)
        print(row['Fabrication_Method'])  
    elif(row['Alloy'].startswith('Y') |row['Alloy'].startswith('(Y')):
        print(row['Alloy'])
        fav=Y(row['Tg'],row['Tx'],row['Tl'],row['Dmax'],row['Heating_Rate1'],row['Heating_Rate2'])
        if(fav ==row['Fabrication_Method']):
            count=count+1
        print(fav)
        print(row['Fabrication_Method'])    
    elif(row['Alloy'].startswith('Fe') | row['Alloy'].startswith('(Fe')| row['Alloy'].startswith('[(Fe')):
        print(row['Alloy'])
        fav=Fe(row['Tg'],row['Tx'],row['Tl'],row['Dmax'],row['Heating_Rate1'],row['Heating_Rate2'])
        if(fav ==row['Fabrication_Method']):
            count=count+1
        print(fav)
        print(row['Fabrication_Method'])    
        
print(count)
print(total_comp)
print((count/total_comp)*100)
# Out:
# Fe63C15Mo14Er2B6
# Cu mold
# Cu mold
# Zr44Au4Cu36Al8Ag8
# Cu mold
# Cu mold
# Fe61B15Mo7Zr8Co5Y2Cr2
# Cu mold D
# Cu moldD
# (Ti0.45Cu0.378Zr0.10Ni0.072)100?6Sn6
# Cu mold D
# Cu mold
# Zr48Cu36Ag8Al8
# Cu mold
# Cu mold
# Ca47.5Mg22.5Cu30
# Cu mold W
# Cu mold W
# Mg57Cu31.5Y9.2Nd2.3
# Cu mold I
# Cu mold I
# Hf47Cu29.25Ni9.75Al14
# Cu mold
# Cu mold
# Cu50Mg18.2Ca31.8
# [586.9779460396977, 622.5771036586552, 270.37544748463165]
# Cu mold I
# Cu mold I
# Ni42Ti20Zr25Al8Cu5
# Cu mold I
# Cu mold
# Fe42.768Co28.512B19.008Si4.752Nb3.96Cr1
# Cu mold D
# Cu mold
# Fe75Mo4P10C4B4Si3
# Cu mold
# Cu mold
# Mg60Ni23.6Si0.5La15.9
# Cu mold W
# Cu mold I
# Fe68W4Y6B22
# Cu mold D
# Cu mold S
# Mg70Ni20La10
# Cu mold I
# Cu mold I
# Zr48Cu37Al7Ag8
# Cu mold
# Cu mold
# Fe64.8Co7.2B19.2Si4.8Nb4
# Cu mold D
# Cu mold I
# (Fe0.73Tb0.02B0.2Si0.05)96Nb4
# Cu mold I
# Cu mold
# Cu45Ag15Zr30Ti10
# [79.30704623888157, 118.91326923434575, 241.20000061115766]
# Cu mold
# Cu mold
# Cu47Ti33Zr11Ni8Si1
# ...
